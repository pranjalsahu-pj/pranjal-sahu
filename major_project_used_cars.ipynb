# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading data and Getting insights

# %%
df = pd.read_csv('/content/used_cars.csv')

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
df.shape
# Out:
# (6019, 14)

# %%
print(f"no of rows -- {df.shape[0]}")
print(f"no of columns -- {df.shape[1]}")
# Out:
# no of rows -- 6019
# no of columns -- 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
df.describe().T
# Out:
#                     count          mean           std      min      25%  \
# Unnamed: 0         6019.0   3009.000000   1737.679967     0.00   1504.5
# Year               6019.0   2013.358199      3.269742  1998.00   2011.0
# Kilometers_Driven  6019.0  58738.380296  91268.843206   171.00  34000.0
# Seats              5977.0      5.278735      0.808840     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
#
#                         50%       75%        max
# Unnamed: 0          3009.00   4513.50     6018.0
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53000.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.nunique()
# Out:
# Unnamed: 0           6019
# Name                 1876
# Location               11
# Year                   22
# Kilometers_Driven    3093
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               442
# Engine                146
# Power                 372
# Seats                   9
# New_Price             540
# Price                1373
# dtype: int64

# %%
df['Year'].min()
df['Year'].max()
# Out:
# 2019

# %% [markdown]
# 1998 -- 2019  years

# %%
df['Location'].value_counts()
# Out:
# Location
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Removing Unwanted Columns

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.shape
# Out:
# (6019, 14)

# %%
df.drop(['Unnamed: 0', 'New_Price'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %% [markdown]
# # Converting numerical with units to plain numerical

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
df.iloc[0:10, 0:2]

# iloc[rows, columns]
# Out:
#                                   Name    Location
# 0               Maruti Wagon R LXI CNG      Mumbai
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune
# 43                    Hyundai i20 Magna Optional 1.2   18.5 kmpl
# 44                  Hyundai Elantra 2.0 SX Option AT  14.62 kmpl
# 45                         Toyota Corolla Altis G AT  14.28 kmpl
# 46                              Hyundai Elantra CRDi   14.9 kmpl
# 47                    Toyota Innova Crysta 2.7 GX MT  11.25 kmpl
# 48                          Hyundai Xcent 1.1 CRDi S   24.4 kmpl
# 49                             Mahindra Thar CRDe AC  16.55 kmpl
# 50              Audi A4 2.0 TDI 177 Bhp Premium Plus  17.11 kmpl
#
#     Kilometers_Driven
# 4               40670
# 5               75000
# 6               86999
# 7               36000
# 8               64430
# 9               65932
# 10              25692
# 11              60000
# 12              64424
# 13              72000
# 14              85000
# 15             110000
# 16              58950
# 17              25000
# 18              77469
# 19              78500
# 20              32982
# 21              55392
# 22              55985
# 23              45807
# 24              33000
# 25              51920
# 26              54000
# 27              54000
# 28              37430
# 29             262000
# 30              62000
# 31              87615
# 32              72000
# 33              35000
# 34              55431
# 35              83816
# 36              50075
# 37              52000
# 38              85000
# 39              62000
# 40              90000
# 41              19698
# 42              22033
# 43              35487
# 44              46374
# 45              52001
# 46              58005
# 47              70704
# 48              75000
# 49              75800
# 50              13648

# %%
df.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 5       LPG       Manual      First  21.1 km/kg   814 CC   55.2 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
# 7    Diesel    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0
# 8    Diesel       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0
# 9    Diesel       Manual     Second   22.3 kmpl  1248 CC     74 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74
# 5   2.35
# 6   3.50
# 7  17.50
# 8   5.20
# 9   1.95

# %%
df.tail(7)
# Out:
#                                      Name    Location  Year  \
# 6012  Toyota Innova 2.5 V Diesel 7-seater  Coimbatore  2011
# 6013                Honda Amaze VX i-DTEC  Coimbatore  2015
# 6014                     Maruti Swift VDI       Delhi  2014
# 6015             Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016                Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017                   Maruti Wagon R VXI     Kolkata  2013
# 6018                Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 6012              45004    Diesel       Manual      First   12.8 kmpl
# 6013              70602    Diesel       Manual      First   25.8 kmpl
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine     Power  Seats  Price
# 6012  2494 CC   102 bhp    7.0   9.48
# 6013  1498 CC  98.6 bhp    5.0   4.83
# 6014  1248 CC    74 bhp    5.0   4.75
# 6015  1120 CC    71 bhp    5.0   4.00
# 6016  2498 CC   112 bhp    8.0   2.90
# 6017   998 CC  67.1 bhp    5.0   2.65
# 6018   936 CC  57.6 bhp    5.0   2.50

# %%
type(df.loc[3, "Mileage"])
# Out:
# str

# %%
df.loc[3, "Mileage"].split()
# Out:
# ['20.77', 'kmpl']

# %%
type(float(df.loc[3, "Mileage"].split()[0]))
# Out:
# float

# %%
def clean_mileage(mileage):
  return float(str(mileage).split()[0]) if pd.notna(mileage) else None

def clean_engine(engine):
  return float(str(engine).split()[0]) if pd.notna(engine) else None

def clean_power(power):
  return float(str(power).split()[0]) if pd.notna(power) and power!= "null bhp" else None

# %%
df["Mileage"] = df["Mileage"].apply(clean_mileage)
df["Engine"] = df["Engine"].apply(clean_engine)
df["Power"] = df["Power"].apply(clean_power)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1       Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2       Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3       Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4       Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# ...        ...          ...        ...      ...     ...     ...    ...    ...
# 6014    Diesel       Manual      First    28.40  1248.0   74.00    5.0   4.75
# 6015    Diesel       Manual      First    24.40  1120.0   71.00    5.0   4.00
# 6016    Diesel       Manual     Second    14.00  2498.0  112.00    8.0   2.90
# 6017    Petrol       Manual      First    18.90   998.0   67.10    5.0   2.65
# 6018    Diesel       Manual      First    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                36
# Power                143
# Seats                 42
# Price                  0
# dtype: int64

# %%
na_cols_to_fill = [x for x in df.columns if df[x].isna().sum() != 0]

# %%
na_cols_to_fill
# Out:
# ['Mileage', 'Engine', 'Power', 'Seats']

# %%
for i in na_cols_to_fill:
  df[i].fillna(df[i].mean(), inplace=True)
# Out:
# <ipython-input-165-d6b19c4108ab>:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df.isna().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1       Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2       Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3       Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4       Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# ...        ...          ...        ...      ...     ...     ...    ...    ...
# 6014    Diesel       Manual      First    28.40  1248.0   74.00    5.0   4.75
# 6015    Diesel       Manual      First    24.40  1120.0   71.00    5.0   4.00
# 6016    Diesel       Manual     Second    14.00  2498.0  112.00    8.0   2.90
# 6017    Petrol       Manual      First    18.90   998.0   67.10    5.0   2.65
# 6018    Diesel       Manual      First    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %% [markdown]
# # Label Encoding

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1       Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2       Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3       Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4       Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# ...        ...          ...        ...      ...     ...     ...    ...    ...
# 6014    Diesel       Manual      First    28.40  1248.0   74.00    5.0   4.75
# 6015    Diesel       Manual      First    24.40  1120.0   71.00    5.0   4.00
# 6016    Diesel       Manual     Second    14.00  2498.0  112.00    8.0   2.90
# 6017    Petrol       Manual      First    18.90   998.0   67.10    5.0   2.65
# 6018    Diesel       Manual      First    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
label_mappings = {}

# %%
cat_cols = [x for x in df.columns if df[x].dtype == "object"]

# %%
cat_cols
# Out:
# ['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type']

# %%
for i in cat_cols:
  df[i] = le.fit_transform(df[i])
  label_mappings[i] = dict(zip(le.classes_, le.transform(le.classes_)))

# %%
label_mappings
# Out:
# {'Name': {'Ambassador Classic Nova Diesel': np.int64(0),
#   'Audi A3 35 TDI Attraction': np.int64(1),
#   'Audi A3 35 TDI Premium': np.int64(2),
#   'Audi A3 35 TDI Premium Plus': np.int64(3),
#   'Audi A3 35 TDI Technology': np.int64(4),
#   'Audi A4 1.8 TFSI': np.int64(5),
#   'Audi A4 1.8 TFSI Technology Edition': np.int64(6),
#   'Audi A4 2.0 TDI': np.int64(7),
#   'Audi A4 2.0 TDI 177 Bhp Premium Plus': np.int64(8),
#   'Audi A4 2.0 TDI 177 Bhp Technology Edition': np.int64(9),
#   'Audi A4 2.0 TDI Celebration Edition': np.int64(10),
#   'Audi A4 2.0 TDI Multitronic': np.int64(11),
#   'Audi A4 2.0 TDI Premium Sport Limited Edition': np.int64(12),
#   'Audi A4 2.0 TFSI': np.int64(13),
#   'Audi A4 3.0 TDI Quattro': np.int64(14),
#   'Audi A4 3.0 TDI Quattro Premium': np.int64(15),
#   'Audi A4 3.2 FSI Tiptronic Quattro': np.int64(16),
#   'Audi A4 30 TFSI Premium Plus': np.int64(17),
#   'Audi A4 35 TDI Premium': np.int64(18),
#   'Audi A4 35 TDI Premium Plus': np.int64(19),
#   'Audi A4 35 TDI Premium Sport': np.int64(20),
#   'Audi A4 35 TDI Technology': np.int64(21),
#   'Audi A4 35 TDI Technology Edition': np.int64(22),
#   'Audi A4 New 2.0 TDI Multitronic': np.int64(23),
#   'Audi A6 2.0 TDI Design Edition': np.int64(24),
#   'Audi A6 2.7 TDI': np.int64(25),
#   'Audi A6 2.8 FSI': np.int64(26),
#   'Audi A6 2011-2015 2.0 TDI': np.int64(27),
#   'Audi A6 2011-2015 2.0 TDI Premium Plus': np.int64(28),
#   'Audi A6 2011-2015 2.0 TDI Technology': np.int64(29),
#   'Audi A6 2011-2015 3.0 TDI Quattro Premium Plus': np.int64(30),
#   'Audi A6 2011-2015 35 TDI Premium': np.int64(31),
#   'Audi A6 2011-2015 35 TDI Technology': np.int64(32),
#   'Audi A6 2011-2015 35 TFSI Technology': np.int64(33),
#   'Audi A6 3.0 TDI quattro': np.int64(34),
#   'Audi A6 35 TDI Matrix': np.int64(35),
#   'Audi A6 35 TFSI Matrix': np.int64(36),
#   'Audi A7 2011-2015 3.0 TDI Quattro': np.int64(37),
#   'Audi A7 2011-2015 Sportback': np.int64(38),
#   'Audi A8 L 3.0 TDI quattro': np.int64(39),
#   'Audi Q3 2.0 TDI': np.int64(40),
#   'Audi Q3 2.0 TDI Quattro': np.int64(41),
#   'Audi Q3 2012-2015 2.0 TDI Quattro Premium Plus': np.int64(42),
#   'Audi Q3 2012-2015 35 TDI Quattro Premium': np.int64(43),
#   'Audi Q3 2012-2015 35 TDI Quattro Premium Plus': np.int64(44),
#   'Audi Q3 30 TDI Premium FWD': np.int64(45),
#   'Audi Q3 35 TDI Quattro Premium': np.int64(46),
#   'Audi Q3 35 TDI Quattro Premium Plus': np.int64(47),
#   'Audi Q5 2.0 TDI': np.int64(48),
#   'Audi Q5 2.0 TDI Premium Plus': np.int64(49),
#   'Audi Q5 2.0 TDI Technology': np.int64(50),
#   'Audi Q5 2008-2012 2.0 TDI': np.int64(51),
#   'Audi Q5 2008-2012 2.0 TFSI Quattro': np.int64(52),
#   'Audi Q5 2008-2012 3.0 TDI': np.int64(53),
#   'Audi Q5 3.0 TDI Quattro': np.int64(54),
#   'Audi Q5 3.0 TDI Quattro Technology': np.int64(55),
#   'Audi Q5 30 TDI quattro Premium': np.int64(56),
#   'Audi Q5 30 TDI quattro Premium Plus': np.int64(57),
#   'Audi Q7 3.0 TDI Quattro Premium Plus': np.int64(58),
#   'Audi Q7 3.0 TDI Quattro Technology': np.int64(59),
#   'Audi Q7 3.0 TDI quattro': np.int64(60),
#   'Audi Q7 35 TDI Quattro Premium Plus': np.int64(61),
#   'Audi Q7 35 TDI Quattro Technology': np.int64(62),
#   'Audi Q7 4.2 FSI quattro': np.int64(63),
#   'Audi Q7 4.2 TDI Quattro Technology': np.int64(64),
#   'Audi Q7 45 TDI Quattro Premium Plus': np.int64(65),
#   'Audi Q7 45 TDI Quattro Technology': np.int64(66),
#   'Audi RS5 Coupe': np.int64(67),
#   'Audi TT 2.0 TFSI': np.int64(68),
#   'Audi TT 40 TFSI': np.int64(69),
#   'BMW 1 Series 118d Base': np.int64(70),
#   'BMW 1 Series 118d Sport Line': np.int64(71),
#   'BMW 3 Series 2005-2011 325i Sedan': np.int64(72),
#   'BMW 3 Series 318i Sedan': np.int64(73),
#   'BMW 3 Series 320d': np.int64(74),
#   'BMW 3 Series 320d Corporate Edition': np.int64(75),
#   'BMW 3 Series 320d Dynamic': np.int64(76),
#   'BMW 3 Series 320d GT Luxury Line': np.int64(77),
#   'BMW 3 Series 320d Highline': np.int64(78),
#   'BMW 3 Series 320d Luxury Line': np.int64(79),
#   'BMW 3 Series 320d Luxury Plus': np.int64(80),
#   'BMW 3 Series 320d M Sport': np.int64(81),
#   'BMW 3 Series 320d Prestige': np.int64(82),
#   'BMW 3 Series 320d Sedan': np.int64(83),
#   'BMW 3 Series 320d Sport': np.int64(84),
#   'BMW 3 Series 320d Sport Line': np.int64(85),
#   'BMW 3 Series 320i': np.int64(86),
#   'BMW 3 Series 320i Sedan': np.int64(87),
#   'BMW 3 Series 328i Sport Line': np.int64(88),
#   'BMW 3 Series 330 Ci Convertible': np.int64(89),
#   'BMW 3 Series 330d Convertible': np.int64(90),
#   'BMW 3 Series 330i': np.int64(91),
#   'BMW 3 Series GT 320d Luxury Line': np.int64(92),
#   'BMW 3 Series Luxury Line': np.int64(93),
#   'BMW 3 Series Sport': np.int64(94),
#   'BMW 5 Series 2003-2012 520d': np.int64(95),
#   'BMW 5 Series 2003-2012 523i': np.int64(96),
#   'BMW 5 Series 2003-2012 525d': np.int64(97),
#   'BMW 5 Series 2003-2012 530d': np.int64(98),
#   'BMW 5 Series 2003-2012 530d Highline': np.int64(99),
#   'BMW 5 Series 2003-2012 540i Sedan': np.int64(100),
#   'BMW 5 Series 2003-2012 GT 530d LE': np.int64(101),
#   'BMW 5 Series 2007-2010 525d Sedan': np.int64(102),
#   'BMW 5 Series 2010-2013 525i': np.int64(103),
#   'BMW 5 Series 2010-2013 530d': np.int64(104),
#   'BMW 5 Series 2013-2017 520d Luxury Line': np.int64(105),
#   'BMW 5 Series 2013-2017 520d M Sport': np.int64(106),
#   'BMW 5 Series 2013-2017 525d Luxury Line': np.int64(107),
#   'BMW 5 Series 2013-2017 530d M Sport': np.int64(108),
#   'BMW 5 Series 520d Luxury Line': np.int64(109),
#   'BMW 5 Series 520d Sedan': np.int64(110),
#   'BMW 5 Series 520d Sport Line': np.int64(111),
#   'BMW 5 Series 523i Sedan': np.int64(112),
#   'BMW 5 Series 525d Sedan': np.int64(113),
#   'BMW 5 Series 530d Highline Sedan': np.int64(114),
#   'BMW 5 Series 530d M Sport': np.int64(115),
#   'BMW 5 Series 530i Sedan': np.int64(116),
#   'BMW 6 Series 630i Coupe': np.int64(117),
#   'BMW 6 Series 640d Coupe': np.int64(118),
#   'BMW 6 Series 640d Gran Coupe': np.int64(119),
#   'BMW 6 Series 650i Coupe': np.int64(120),
#   'BMW 6 Series Gran Coupe': np.int64(121),
#   'BMW 7 Series 2007-2012 730Ld': np.int64(122),
#   'BMW 7 Series 2007-2012 740Li': np.int64(123),
#   'BMW 7 Series 2007-2012 750Li': np.int64(124),
#   'BMW 7 Series 730Ld': np.int64(125),
#   'BMW 7 Series 730Ld Design Pure Excellence CBU': np.int64(126),
#   'BMW 7 Series 730Ld Eminence': np.int64(127),
#   'BMW 7 Series 730Ld Sedan': np.int64(128),
#   'BMW 7 Series 740Li': np.int64(129),
#   'BMW X1 M Sport sDrive 20d': np.int64(130),
#   'BMW X1 sDrive 18i': np.int64(131),
#   'BMW X1 sDrive 20d Exclusive': np.int64(132),
#   'BMW X1 sDrive 20d Sportline': np.int64(133),
#   'BMW X1 sDrive 20d xLine': np.int64(134),
#   'BMW X1 sDrive20d': np.int64(135),
#   'BMW X1 xDrive 20d M Sport': np.int64(136),
#   'BMW X1 xDrive 20d xLine': np.int64(137),
#   'BMW X3 xDrive 20d Expedition': np.int64(138),
#   'BMW X3 xDrive 20d Luxury Line': np.int64(139),
#   'BMW X3 xDrive 20d xLine': np.int64(140),
#   'BMW X3 xDrive20d': np.int64(141),
#   'BMW X3 xDrive20d Advantage Edition': np.int64(142),
#   'BMW X3 xDrive20d Expedition': np.int64(143),
#   'BMW X3 xDrive20d xLine': np.int64(144),
#   'BMW X3 xDrive30d M Sport': np.int64(145),
#   'BMW X5 2014-2019 xDrive 30d Design Pure Experience 7 Seater': np.int64(146),
#   'BMW X5 3.0d': np.int64(147),
#   'BMW X5 X5 M': np.int64(148),
#   'BMW X5 xDrive 30d': np.int64(149),
#   'BMW X5 xDrive 30d Design Pure Experience 5 Seater': np.int64(150),
#   'BMW X5 xDrive 30d M Sport': np.int64(151),
#   'BMW X6 xDrive 40d': np.int64(152),
#   'BMW X6 xDrive 40d M Sport': np.int64(153),
#   'BMW X6 xDrive30d': np.int64(154),
#   'BMW Z4 2009-2013 35i': np.int64(155),
#   'BMW Z4 2009-2013 Roadster 2.5i': np.int64(156),
#   'Bentley Continental Flying Spur': np.int64(157),
#   'Chevrolet Aveo 1.4': np.int64(158),
#   'Chevrolet Aveo 1.4 LS': np.int64(159),
#   'Chevrolet Aveo 1.4 LT': np.int64(160),
#   'Chevrolet Aveo 1.4 LT ABS BSIV': np.int64(161),
#   'Chevrolet Aveo 1.6 LT': np.int64(162),
#   'Chevrolet Aveo U-VA 1.2 LS': np.int64(163),
#   'Chevrolet Aveo U-VA 1.2 LT': np.int64(164),
#   'Chevrolet Beat Diesel': np.int64(165),
#   'Chevrolet Beat Diesel LS': np.int64(166),
#   'Chevrolet Beat Diesel LT': np.int64(167),
#   'Chevrolet Beat Diesel PS': np.int64(168),
#   'Chevrolet Beat LS': np.int64(169),
#   'Chevrolet Beat LT': np.int64(170),
#   'Chevrolet Beat LT Option': np.int64(171),
#   'Chevrolet Beat Option Pack': np.int64(172),
#   'Chevrolet Captiva LT': np.int64(173),
#   'Chevrolet Captiva LTZ VCDi': np.int64(174),
#   'Chevrolet Cruze LTZ': np.int64(175),
#   'Chevrolet Cruze LTZ AT': np.int64(176),
#   'Chevrolet Enjoy 1.3 TCDi LS 8': np.int64(177),
#   'Chevrolet Enjoy 1.3 TCDi LTZ 8': np.int64(178),
#   'Chevrolet Enjoy 1.4 LS 8': np.int64(179),
#   'Chevrolet Enjoy Petrol LS 7 Seater': np.int64(180),
#   'Chevrolet Enjoy TCDi LS 8 Seater': np.int64(181),
#   'Chevrolet Enjoy TCDi LTZ 7 Seater': np.int64(182),
#   'Chevrolet Optra 1.6 Elite': np.int64(183),
#   'Chevrolet Optra 1.6 LS': np.int64(184),
#   'Chevrolet Optra 1.6 LT Royale': np.int64(185),
#   'Chevrolet Optra Magnum 1.6 LS BS3': np.int64(186),
#   'Chevrolet Optra Magnum 1.6 LS Petrol': np.int64(187),
#   'Chevrolet Optra Magnum 1.6 LT ABS BS3': np.int64(188),
#   'Chevrolet Optra Magnum 2.0 LS BSIII': np.int64(189),
#   'Chevrolet Optra Magnum 2.0 LT': np.int64(190),
#   'Chevrolet Optra Magnum 2.0 LT BS3': np.int64(191),
#   'Chevrolet Sail 1.2 LS': np.int64(192),
#   'Chevrolet Sail Hatchback 1.2 LS': np.int64(193),
#   'Chevrolet Sail Hatchback 1.2 LS ABS': np.int64(194),
#   'Chevrolet Sail Hatchback LS ABS': np.int64(195),
#   'Chevrolet Sail LT ABS': np.int64(196),
#   'Chevrolet Spark 1.0 LS': np.int64(197),
#   'Chevrolet Spark 1.0 LT': np.int64(198),
#   'Chevrolet Tavera LS B3 10 Seats BSIII': np.int64(199),
#   'Chevrolet Tavera LT 9 Str BS IV': np.int64(200),
#   'Datsun GO NXT': np.int64(201),
#   'Datsun GO Plus A': np.int64(202),
#   'Datsun GO Plus T': np.int64(203),
#   'Datsun GO Plus T Petrol': np.int64(204),
#   'Datsun GO T Option': np.int64(205),
#   'Datsun Redi GO Sport': np.int64(206),
#   'Datsun redi-GO S': np.int64(207),
#   'Datsun redi-GO T': np.int64(208),
#   'Datsun redi-GO T Option': np.int64(209),
#   'Fiat Avventura MULTIJET Emotion': np.int64(210),
#   'Fiat Grande Punto 1.2 Dynamic': np.int64(211),
#   'Fiat Grande Punto 1.3 Emotion (Diesel)': np.int64(212),
#   'Fiat Grande Punto 1.3 Emotion Pack (Diesel)': np.int64(213),
#   'Fiat Grande Punto 1.4 Emotion': np.int64(214),
#   'Fiat Grande Punto EVO 1.3 Active': np.int64(215),
#   'Fiat Linea 1.3 Dynamic': np.int64(216),
#   'Fiat Linea 1.3 Emotion': np.int64(217),
#   'Fiat Linea Classic Plus 1.3 Multijet': np.int64(218),
#   'Fiat Linea Emotion': np.int64(219),
#   'Fiat Linea Emotion (Diesel)': np.int64(220),
#   'Fiat Linea Emotion Pack (Diesel)': np.int64(221),
#   'Fiat Linea T Jet': np.int64(222),
#   'Fiat Linea T-Jet Active': np.int64(223),
#   'Fiat Petra 1.2 EL': np.int64(224),
#   'Fiat Punto 1.2 Dynamic': np.int64(225),
#   'Fiat Punto 1.3 Emotion': np.int64(226),
#   'Fiat Punto 1.4 Emotion': np.int64(227),
#   'Fiat Punto EVO 1.2 Emotion': np.int64(228),
#   'Fiat Siena 1.2 ELX': np.int64(229),
#   'Force One LX 4x4': np.int64(230),
#   'Force One LX ABS 7 Seating': np.int64(231),
#   'Ford Aspire Ambiente Diesel': np.int64(232),
#   'Ford Aspire Titanium Diesel': np.int64(233),
#   'Ford Aspire Titanium Plus Diesel': np.int64(234),
#   'Ford Classic 1.4 Duratorq Titanium': np.int64(235),
#   'Ford EcoSport 1.0 Ecoboost Titanium Plus': np.int64(236),
#   'Ford EcoSport 1.0 Ecoboost Titanium Plus BE': np.int64(237),
#   'Ford EcoSport 1.5 Diesel Titanium': np.int64(238),
#   'Ford EcoSport 1.5 Diesel Titanium Plus': np.int64(239),
#   'Ford EcoSport 1.5 Diesel Trend': np.int64(240),
#   'Ford EcoSport 1.5 Petrol Titanium': np.int64(241),
#   'Ford EcoSport 1.5 Petrol Titanium Plus AT': np.int64(242),
#   'Ford EcoSport 1.5 Petrol Trend': np.int64(243),
#   'Ford EcoSport 1.5 TDCi Ambiente': np.int64(244),
#   'Ford EcoSport 1.5 TDCi Titanium': np.int64(245),
#   'Ford EcoSport 1.5 TDCi Trend': np.int64(246),
#   'Ford EcoSport 1.5 TDCi Trend Plus': np.int64(247),
#   'Ford EcoSport 1.5 TDCi Trend Plus BE': np.int64(248),
#   'Ford EcoSport 1.5 Ti VCT AT Titanium': np.int64(249),
#   'Ford EcoSport 1.5 Ti VCT AT Titanium BE': np.int64(250),
#   'Ford EcoSport 1.5 Ti VCT MT Signature': np.int64(251),
#   'Ford EcoSport 1.5 Ti VCT MT Titanium': np.int64(252),
#   'Ford EcoSport 1.5 Ti VCT MT Titanium BE': np.int64(253),
#   'Ford Ecosport 1.0 Ecoboost Platinum Edition': np.int64(254),
#   'Ford Ecosport 1.0 Ecoboost Titanium': np.int64(255),
#   'Ford Ecosport 1.5 DV5 MT Ambiente': np.int64(256),
#   'Ford Ecosport 1.5 DV5 MT Titanium': np.int64(257),
#   'Ford Ecosport 1.5 DV5 MT Titanium Optional': np.int64(258),
#   'Ford Ecosport 1.5 DV5 MT Trend': np.int64(259),
#   'Ford Ecosport 1.5 Ti VCT AT Titanium': np.int64(260),
#   'Ford Ecosport 1.5 Ti VCT MT Titanium': np.int64(261),
#   'Ford Ecosport 1.5 Ti VCT MT Trend': np.int64(262),
#   'Ford Ecosport Signature Edition Diesel': np.int64(263),
#   'Ford Endeavour 2.2 Titanium AT 4X2': np.int64(264),
#   'Ford Endeavour 2.2 Trend AT 4X2': np.int64(265),
#   'Ford Endeavour 2.2 Trend MT 4X4': np.int64(266),
#   'Ford Endeavour 2.5L 4X2': np.int64(267),
#   'Ford Endeavour 2.5L 4X2 MT': np.int64(268),
#   'Ford Endeavour 3.0L 4X4 AT': np.int64(269),
#   'Ford Endeavour 3.2 Titanium AT 4X4': np.int64(270),
#   'Ford Endeavour 3.2 Trend AT 4X4': np.int64(271),
#   'Ford Endeavour 4x2 XLT': np.int64(272),
#   'Ford Endeavour 4x2 XLT Limited Edition': np.int64(273),
#   'Ford Endeavour Hurricane LE': np.int64(274),
#   'Ford Endeavour Hurricane Limited Edition': np.int64(275),
#   'Ford Endeavour Titanium 4X2': np.int64(276),
#   'Ford Endeavour XLT TDCi 4X2': np.int64(277),
#   'Ford Endeavour XLT TDCi 4X4': np.int64(278),
#   'Ford Fiesta 1.4 Duratec EXI': np.int64(279),
#   'Ford Fiesta 1.4 Duratec EXI Limited Edition': np.int64(280),
#   'Ford Fiesta 1.4 Duratec ZXI': np.int64(281),
#   'Ford Fiesta 1.4 Duratorq EXI': np.int64(282),
#   'Ford Fiesta 1.4 Duratorq ZXI': np.int64(283),
#   'Ford Fiesta 1.4 SXi TDCi': np.int64(284),
#   'Ford Fiesta 1.4 SXi TDCi ABS': np.int64(285),
#   'Ford Fiesta 1.4 TDCi EXI': np.int64(286),
#   'Ford Fiesta 1.4 TDCi EXI Limited Edition': np.int64(287),
#   'Ford Fiesta 1.4 ZXi Duratec': np.int64(288),
#   'Ford Fiesta 1.4 ZXi Leather': np.int64(289),
#   'Ford Fiesta 1.4 ZXi TDCi ABS': np.int64(290),
#   'Ford Fiesta 1.5 TDCi Titanium': np.int64(291),
#   'Ford Fiesta 1.6 SXI ABS Duratec': np.int64(292),
#   'Ford Fiesta 1.6 ZXI Duratec': np.int64(293),
#   'Ford Fiesta 1.6 ZXi ABS': np.int64(294),
#   'Ford Fiesta 1.6 ZXi Duratec': np.int64(295),
#   'Ford Fiesta 1.6 ZXi Leather': np.int64(296),
#   'Ford Fiesta Classic 1.4 Duratorq CLXI': np.int64(297),
#   'Ford Fiesta Classic 1.4 Duratorq LXI': np.int64(298),
#   'Ford Fiesta Diesel Style': np.int64(299),
#   'Ford Fiesta Diesel Titanium Plus': np.int64(300),
#   'Ford Fiesta Diesel Trend': np.int64(301),
#   'Ford Fiesta EXi 1.4 TDCi Ltd': np.int64(302),
#   'Ford Fiesta Titanium 1.5 TDCi': np.int64(303),
#   'Ford Figo 1.2P Titanium MT': np.int64(304),
#   'Ford Figo 1.5D Titanium Plus MT': np.int64(305),
#   'Ford Figo 1.5D Trend MT': np.int64(306),
#   'Ford Figo 2015-2019 1.2P Sports Edition MT': np.int64(307),
#   'Ford Figo 2015-2019 1.2P Titanium MT': np.int64(308),
#   'Ford Figo 2015-2019 1.2P Titanium Opt MT': np.int64(309),
#   'Ford Figo 2015-2019 1.2P Trend MT': np.int64(310),
#   'Ford Figo 2015-2019 1.5D Ambiente MT': np.int64(311),
#   'Ford Figo 2015-2019 1.5D Titanium MT': np.int64(312),
#   'Ford Figo 2015-2019 1.5D Titanium Plus MT': np.int64(313),
#   'Ford Figo 2015-2019 1.5D Trend MT': np.int64(314),
#   'Ford Figo 2015-2019 1.5P Titanium AT': np.int64(315),
#   'Ford Figo Aspire 1.2 Ti-VCT Ambiente': np.int64(316),
#   'Ford Figo Aspire 1.2 Ti-VCT Titanium': np.int64(317),
#   'Ford Figo Aspire 1.2 Ti-VCT Trend': np.int64(318),
#   'Ford Figo Aspire 1.5 TDCi Ambiente': np.int64(319),
#   'Ford Figo Aspire 1.5 TDCi Titanium': np.int64(320),
#   'Ford Figo Aspire 1.5 TDCi Titanium Plus': np.int64(321),
#   'Ford Figo Aspire 1.5 TDCi Trend': np.int64(322),
#   'Ford Figo Aspire 1.5 Ti-VCT Titanium': np.int64(323),
#   'Ford Figo Diesel': np.int64(324),
#   'Ford Figo Diesel Celebration Edition': np.int64(325),
#   'Ford Figo Diesel EXI': np.int64(326),
#   'Ford Figo Diesel EXI Option': np.int64(327),
#   'Ford Figo Diesel LXI': np.int64(328),
#   'Ford Figo Diesel Titanium': np.int64(329),
#   'Ford Figo Diesel ZXI': np.int64(330),
#   'Ford Figo Petrol EXI': np.int64(331),
#   'Ford Figo Petrol LXI': np.int64(332),
#   'Ford Figo Petrol Titanium': np.int64(333),
#   'Ford Figo Petrol ZXI': np.int64(334),
#   'Ford Figo Titanium Diesel': np.int64(335),
#   'Ford Freestyle Titanium Petrol': np.int64(336),
#   'Ford Freestyle Titanium Plus Petrol': np.int64(337),
#   'Ford Fusion Plus 1.4 TDCi Diesel': np.int64(338),
#   'Ford Ikon 1.3 CLXi': np.int64(339),
#   'Ford Ikon 1.3 Flair': np.int64(340),
#   'Ford Ikon 1.3 LXi NXt': np.int64(341),
#   'Ford Ikon 1.4 TDCi DuraTorq': np.int64(342),
#   'Ford Ikon 1.6 CLXI': np.int64(343),
#   'Ford Ikon 1.6 ZXI NXt': np.int64(344),
#   'Ford Mustang V8': np.int64(345),
#   'Honda Accord 2.4 A/T': np.int64(346),
#   'Honda Accord 2.4 AT': np.int64(347),
#   'Honda Accord 2.4 Elegance A/T': np.int64(348),
#   'Honda Accord 2.4 Elegance M/T': np.int64(349),
#   'Honda Accord 2.4 Inspire M/T': np.int64(350),
#   'Honda Accord 2.4 M/T': np.int64(351),
#   'Honda Accord 2.4 MT': np.int64(352),
#   'Honda Accord 2001-2003 2.0 AT': np.int64(353),
#   'Honda Accord 2001-2003 2.3 VTi L AT': np.int64(354),
#   'Honda Accord V6 AT': np.int64(355),
#   'Honda Accord VTi-L (AT)': np.int64(356),
#   'Honda Accord VTi-L AT': np.int64(357),
#   'Honda Accord VTi-L MT': np.int64(358),
#   'Honda Amaze E i-Dtech': np.int64(359),
#   'Honda Amaze E i-Vtech': np.int64(360),
#   'Honda Amaze EX i-Dtech': np.int64(361),
#   'Honda Amaze EX i-Vtech': np.int64(362),
#   'Honda Amaze S AT i-Vtech': np.int64(363),
#   'Honda Amaze S Diesel': np.int64(364),
#   'Honda Amaze S Petrol': np.int64(365),
#   'Honda Amaze S i-DTEC': np.int64(366),
#   'Honda Amaze S i-Dtech': np.int64(367),
#   'Honda Amaze S i-VTEC': np.int64(368),
#   'Honda Amaze S i-Vtech': np.int64(369),
#   'Honda Amaze SX i-DTEC': np.int64(370),
#   'Honda Amaze SX i-VTEC': np.int64(371),
#   'Honda Amaze V CVT Petrol': np.int64(372),
#   'Honda Amaze V Petrol': np.int64(373),
#   'Honda Amaze VX AT i-Vtech': np.int64(374),
#   'Honda Amaze VX Diesel': np.int64(375),
#   'Honda Amaze VX O i VTEC': np.int64(376),
#   'Honda Amaze VX Petrol': np.int64(377),
#   'Honda Amaze VX i-DTEC': np.int64(378),
#   'Honda Amaze VX i-VTEC': np.int64(379),
#   'Honda Amaze VX i-Vtech': np.int64(380),
#   'Honda BR-V i-DTEC VX MT': np.int64(381),
#   'Honda BR-V i-VTEC S MT': np.int64(382),
#   'Honda BRV i-VTEC V CVT': np.int64(383),
#   'Honda BRV i-VTEC V MT': np.int64(384),
#   'Honda Brio 1.2 S MT': np.int64(385),
#   'Honda Brio 1.2 S Option MT': np.int64(386),
#   'Honda Brio 1.2 VX AT': np.int64(387),
#   'Honda Brio 1.2 VX MT': np.int64(388),
#   'Honda Brio E MT': np.int64(389),
#   'Honda Brio EX MT': np.int64(390),
#   'Honda Brio S MT': np.int64(391),
#   'Honda Brio S Option AT': np.int64(392),
#   'Honda Brio S Option MT': np.int64(393),
#   'Honda Brio V MT': np.int64(394),
#   'Honda Brio VX': np.int64(395),
#   'Honda Brio VX AT': np.int64(396),
#   'Honda CR-V 2.0 AT': np.int64(397),
#   'Honda CR-V 2.0L 2WD AT': np.int64(398),
#   'Honda CR-V 2.0L 2WD MT': np.int64(399),
#   'Honda CR-V 2.4 4WD AT': np.int64(400),
#   'Honda CR-V 2.4 AT': np.int64(401),
#   'Honda CR-V 2.4 MT': np.int64(402),
#   'Honda CR-V 2.4L 4WD AT': np.int64(403),
#   'Honda CR-V 2.4L 4WD AT AVN': np.int64(404),
#   'Honda CR-V 2.4L 4WD MT': np.int64(405),
#   'Honda CR-V AT With Sun Roof': np.int64(406),
#   'Honda CR-V Petrol 2WD': np.int64(407),
#   'Honda CR-V RVi MT': np.int64(408),
#   'Honda CR-V Sport': np.int64(409),
#   'Honda City 1.3 DX': np.int64(410),
#   'Honda City 1.3 EXI': np.int64(411),
#   'Honda City 1.3 EXI S': np.int64(412),
#   'Honda City 1.5 E MT': np.int64(413),
#   'Honda City 1.5 EXI': np.int64(414),
#   'Honda City 1.5 EXI AT': np.int64(415),
#   'Honda City 1.5 EXI S': np.int64(416),
#   'Honda City 1.5 GXI': np.int64(417),
#   'Honda City 1.5 S AT': np.int64(418),
#   'Honda City 1.5 S MT': np.int64(419),
#   'Honda City 1.5 V AT': np.int64(420),
#   'Honda City 1.5 V AT Exclusive': np.int64(421),
#   'Honda City 1.5 V AT Sunroof': np.int64(422),
#   'Honda City 1.5 V MT': np.int64(423),
#   'Honda City 1.5 V MT Exclusive': np.int64(424),
#   'Honda City 1.5 V MT Sunroof': np.int64(425),
#   'Honda City Corporate Edition': np.int64(426),
#   'Honda City V AT': np.int64(427),
#   'Honda City V MT': np.int64(428),
#   'Honda City V MT AVN': np.int64(429),
#   'Honda City V MT Exclusive': np.int64(430),
#   'Honda City ZX CVT': np.int64(431),
#   'Honda City ZX EXi': np.int64(432),
#   'Honda City ZX GXi': np.int64(433),
#   'Honda City ZX VTEC': np.int64(434),
#   'Honda City i DTEC S': np.int64(435),
#   'Honda City i DTEC SV': np.int64(436),
#   'Honda City i DTEC V': np.int64(437),
#   'Honda City i DTEC VX': np.int64(438),
#   'Honda City i DTEC VX Option': np.int64(439),
#   'Honda City i DTec E': np.int64(440),
#   'Honda City i DTec S': np.int64(441),
#   'Honda City i DTec SV': np.int64(442),
#   'Honda City i DTec V': np.int64(443),
#   'Honda City i DTec VX': np.int64(444),
#   'Honda City i VTEC CVT SV': np.int64(445),
#   'Honda City i VTEC CVT VX': np.int64(446),
#   'Honda City i VTEC E': np.int64(447),
#   'Honda City i VTEC S': np.int64(448),
#   'Honda City i VTEC SV': np.int64(449),
#   'Honda City i VTEC V': np.int64(450),
#   'Honda City i VTEC VX': np.int64(451),
#   'Honda City i VTEC VX Option': np.int64(452),
#   'Honda City i-DTEC SV': np.int64(453),
#   'Honda City i-DTEC ZX': np.int64(454),
#   'Honda City i-VTEC CVT V': np.int64(455),
#   'Honda City i-VTEC CVT VX': np.int64(456),
#   'Honda City i-VTEC CVT ZX': np.int64(457),
#   'Honda City i-VTEC S': np.int64(458),
#   'Honda City i-VTEC V': np.int64(459),
#   'Honda City i-VTEC VX': np.int64(460),
#   'Honda Civic 2006-2010 1.8 (E) MT': np.int64(461),
#   'Honda Civic 2006-2010 1.8 MT Sport': np.int64(462),
#   'Honda Civic 2006-2010 1.8 S AT': np.int64(463),
#   'Honda Civic 2006-2010 1.8 S MT': np.int64(464),
#   'Honda Civic 2006-2010 1.8 V AT': np.int64(465),
#   'Honda Civic 2006-2010 1.8 V MT': np.int64(466),
#   'Honda Civic 2010-2013 1.8 S MT': np.int64(467),
#   'Honda Civic 2010-2013 1.8 V AT Sunroof': np.int64(468),
#   'Honda Civic 2010-2013 1.8 V MT': np.int64(469),
#   'Honda Jazz 1.2 E i VTEC': np.int64(470),
#   'Honda Jazz 1.2 S i VTEC': np.int64(471),
#   'Honda Jazz 1.2 SV i VTEC': np.int64(472),
#   'Honda Jazz 1.2 V AT i VTEC Privilege': np.int64(473),
#   'Honda Jazz 1.2 V CVT i VTEC': np.int64(474),
#   'Honda Jazz 1.2 V i VTEC': np.int64(475),
#   'Honda Jazz 1.2 VX i VTEC': np.int64(476),
#   'Honda Jazz 1.5 S i DTEC': np.int64(477),
#   'Honda Jazz 1.5 SV i DTEC': np.int64(478),
#   'Honda Jazz 1.5 V i DTEC': np.int64(479),
#   'Honda Jazz 1.5 VX i DTEC': np.int64(480),
#   'Honda Jazz Active': np.int64(481),
#   'Honda Jazz Exclusive CVT': np.int64(482),
#   'Honda Jazz Mode': np.int64(483),
#   'Honda Jazz S': np.int64(484),
#   'Honda Jazz Select Edition': np.int64(485),
#   'Honda Jazz V': np.int64(486),
#   'Honda Jazz V CVT': np.int64(487),
#   'Honda Jazz VX': np.int64(488),
#   'Honda Jazz VX Diesel': np.int64(489),
#   'Honda Mobilio E i DTEC': np.int64(490),
#   'Honda Mobilio E i VTEC': np.int64(491),
#   'Honda Mobilio RS Option i DTEC': np.int64(492),
#   'Honda Mobilio RS i DTEC': np.int64(493),
#   'Honda Mobilio S i DTEC': np.int64(494),
#   'Honda Mobilio S i VTEC': np.int64(495),
#   'Honda Mobilio V Option i DTEC': np.int64(496),
#   'Honda Mobilio V i DTEC': np.int64(497),
#   'Honda WR-V Edge Edition i-VTEC S': np.int64(498),
#   'Honda WRV i-VTEC VX': np.int64(499),
#   'Hyundai Accent CRDi': np.int64(500),
#   'Hyundai Accent Executive': np.int64(501),
#   'Hyundai Accent Executive CNG': np.int64(502),
#   'Hyundai Accent GLE': np.int64(503),
#   'Hyundai Accent GLE 1': np.int64(504),
#   'Hyundai Accent GLS': np.int64(505),
#   'Hyundai Accent GLS 1.6': np.int64(506),
#   'Hyundai Creta 1.4 CRDi S': np.int64(507),
#   'Hyundai Creta 1.4 CRDi S Plus': np.int64(508),
#   'Hyundai Creta 1.4 E Plus Diesel': np.int64(509),
#   'Hyundai Creta 1.6 CRDi AT SX Plus': np.int64(510),
#   'Hyundai Creta 1.6 CRDi SX': np.int64(511),
#   'Hyundai Creta 1.6 CRDi SX Option': np.int64(512),
#   'Hyundai Creta 1.6 SX': np.int64(513),
#   'Hyundai Creta 1.6 SX Automatic Diesel': np.int64(514),
#   'Hyundai Creta 1.6 SX Option': np.int64(515),
#   'Hyundai Creta 1.6 SX Option Diesel': np.int64(516),
#   'Hyundai Creta 1.6 SX Option Executive': np.int64(517),
#   'Hyundai Creta 1.6 SX Plus Diesel': np.int64(518),
#   'Hyundai Creta 1.6 SX Plus Dual Tone Petrol': np.int64(519),
#   'Hyundai Creta 1.6 SX Plus Petrol Automatic': np.int64(520),
#   'Hyundai Creta 1.6 VTVT E Plus': np.int64(521),
#   'Hyundai Creta 1.6 VTVT S': np.int64(522),
#   'Hyundai EON 1.0 Kappa Magna Plus Optional': np.int64(523),
#   'Hyundai EON 1.0 Magna Plus Option O': np.int64(524),
#   'Hyundai EON D Lite': np.int64(525),
#   'Hyundai EON D Lite Plus': np.int64(526),
#   'Hyundai EON D Lite Plus Option': np.int64(527),
#   'Hyundai EON Era': np.int64(528),
#   'Hyundai EON Era Plus': np.int64(529),
#   'Hyundai EON LPG Era Plus Option': np.int64(530),
#   'Hyundai EON Magna': np.int64(531),
#   'Hyundai EON Magna Plus': np.int64(532),
#   'Hyundai EON Sportz': np.int64(533),
#   'Hyundai Elantra 1.6 SX': np.int64(534),
#   'Hyundai Elantra 1.6 SX Option AT': np.int64(535),
#   'Hyundai Elantra 2.0 SX Option AT': np.int64(536),
#   'Hyundai Elantra CRDi': np.int64(537),
#   'Hyundai Elantra CRDi S': np.int64(538),
#   'Hyundai Elantra CRDi SX': np.int64(539),
#   'Hyundai Elantra CRDi SX AT': np.int64(540),
#   'Hyundai Elantra SX': np.int64(541),
#   'Hyundai Elite i20 Asta Option': np.int64(542),
#   'Hyundai Elite i20 Diesel Asta Option': np.int64(543),
#   'Hyundai Elite i20 Petrol Asta': np.int64(544),
#   'Hyundai Elite i20 Petrol Sportz': np.int64(545),
#   'Hyundai Elite i20 Sportz Plus': np.int64(546),
#   'Hyundai Getz 1.3 GLS': np.int64(547),
#   'Hyundai Getz 1.5 CRDi GVS': np.int64(548),
#   'Hyundai Getz GLE': np.int64(549),
#   'Hyundai Getz GLS': np.int64(550),
#   'Hyundai Getz GLS ABS': np.int64(551),
#   'Hyundai Getz GVS': np.int64(552),
#   'Hyundai Grand i10 1.2 CRDi Asta': np.int64(553),
#   'Hyundai Grand i10 1.2 CRDi Magna': np.int64(554),
#   'Hyundai Grand i10 1.2 CRDi Sportz': np.int64(555),
#   'Hyundai Grand i10 1.2 CRDi Sportz Option': np.int64(556),
#   'Hyundai Grand i10 1.2 Kappa Asta': np.int64(557),
#   'Hyundai Grand i10 1.2 Kappa Magna': np.int64(558),
#   'Hyundai Grand i10 1.2 Kappa Magna AT': np.int64(559),
#   'Hyundai Grand i10 1.2 Kappa Sportz': np.int64(560),
#   'Hyundai Grand i10 1.2 Kappa Sportz AT': np.int64(561),
#   'Hyundai Grand i10 1.2 Kappa Sportz Option': np.int64(562),
#   'Hyundai Grand i10 AT Asta': np.int64(563),
#   'Hyundai Grand i10 Asta': np.int64(564),
#   'Hyundai Grand i10 Asta Option': np.int64(565),
#   'Hyundai Grand i10 Asta Option AT': np.int64(566),
#   'Hyundai Grand i10 CRDi Asta': np.int64(567),
#   'Hyundai Grand i10 CRDi Era': np.int64(568),
#   'Hyundai Grand i10 CRDi Magna': np.int64(569),
#   'Hyundai Grand i10 CRDi SportZ Edition': np.int64(570),
#   'Hyundai Grand i10 CRDi Sportz': np.int64(571),
#   'Hyundai Grand i10 CRDi Sportz Celebration Edition': np.int64(572),
#   'Hyundai Grand i10 Era': np.int64(573),
#   'Hyundai Grand i10 Magna': np.int64(574),
#   'Hyundai Grand i10 Magna AT': np.int64(575),
#   'Hyundai Grand i10 SportZ Edition': np.int64(576),
#   'Hyundai Grand i10 Sportz': np.int64(577),
#   'Hyundai Santa Fe 2WD AT': np.int64(578),
#   'Hyundai Santa Fe 4WD AT': np.int64(579),
#   'Hyundai Santa Fe 4X2': np.int64(580),
#   'Hyundai Santa Fe 4X4': np.int64(581),
#   'Hyundai Santa Fe 4x4 AT': np.int64(582),
#   'Hyundai Santro AT': np.int64(583),
#   'Hyundai Santro D Lite': np.int64(584),
#   'Hyundai Santro DX': np.int64(585),
#   'Hyundai Santro GLS I - Euro I': np.int64(586),
#   'Hyundai Santro GLS I - Euro II': np.int64(587),
#   'Hyundai Santro GLS II - Euro II': np.int64(588),
#   'Hyundai Santro GS': np.int64(589),
#   'Hyundai Santro GS zipDrive - Euro II': np.int64(590),
#   'Hyundai Santro LP - Euro II': np.int64(591),
#   'Hyundai Santro LP zipPlus': np.int64(592),
#   'Hyundai Santro LS zipPlus': np.int64(593),
#   'Hyundai Santro Xing GL': np.int64(594),
#   'Hyundai Santro Xing GL Plus': np.int64(595),
#   'Hyundai Santro Xing GL Plus LPG': np.int64(596),
#   'Hyundai Santro Xing GLS': np.int64(597),
#   'Hyundai Santro Xing GLS LPG': np.int64(598),
#   'Hyundai Santro Xing XG': np.int64(599),
#   'Hyundai Santro Xing XG eRLX Euro III': np.int64(600),
#   'Hyundai Santro Xing XL': np.int64(601),
#   'Hyundai Santro Xing XL AT eRLX Euro II': np.int64(602),
#   'Hyundai Santro Xing XL AT eRLX Euro III': np.int64(603),
#   'Hyundai Santro Xing XL eRLX Euro III': np.int64(604),
#   'Hyundai Santro Xing XO': np.int64(605),
#   'Hyundai Santro Xing XO CNG': np.int64(606),
#   'Hyundai Santro Xing XO eRLX Euro II': np.int64(607),
#   'Hyundai Santro Xing XP': np.int64(608),
#   'Hyundai Sonata 2.4 GDI': np.int64(609),
#   'Hyundai Sonata Embera 2.0L CRDi AT': np.int64(610),
#   'Hyundai Sonata Embera 2.0L CRDi MT': np.int64(611),
#   'Hyundai Sonata GOLD': np.int64(612),
#   'Hyundai Sonata Transform 2.4 GDi AT': np.int64(613),
#   'Hyundai Sonata Transform 2.4 GDi MT': np.int64(614),
#   'Hyundai Tucson 2.0 Dual VTVT 2WD AT GL': np.int64(615),
#   'Hyundai Tucson 2.0 e-VGT 2WD AT GLS': np.int64(616),
#   'Hyundai Tucson CRDi': np.int64(617),
#   'Hyundai Verna 1.4 CRDi': np.int64(618),
#   'Hyundai Verna 1.4 CRDi GL': np.int64(619),
#   'Hyundai Verna 1.4 CX VTVT': np.int64(620),
#   'Hyundai Verna 1.4 EX': np.int64(621),
#   'Hyundai Verna 1.4 VTVT': np.int64(622),
#   'Hyundai Verna 1.6 CRDI': np.int64(623),
#   'Hyundai Verna 1.6 CRDI AT SX Option': np.int64(624),
#   'Hyundai Verna 1.6 CRDI SX Option': np.int64(625),
#   'Hyundai Verna 1.6 CRDi AT S': np.int64(626),
#   'Hyundai Verna 1.6 CRDi AT SX': np.int64(627),
#   'Hyundai Verna 1.6 CRDi EX AT': np.int64(628),
#   'Hyundai Verna 1.6 CRDi EX MT': np.int64(629),
#   'Hyundai Verna 1.6 CRDi S': np.int64(630),
#   'Hyundai Verna 1.6 CRDi SX': np.int64(631),
#   'Hyundai Verna 1.6 EX VTVT': np.int64(632),
#   'Hyundai Verna 1.6 SX': np.int64(633),
#   'Hyundai Verna 1.6 SX CRDI (O) AT': np.int64(634),
#   'Hyundai Verna 1.6 SX CRDi (O)': np.int64(635),
#   'Hyundai Verna 1.6 SX VTVT': np.int64(636),
#   'Hyundai Verna 1.6 SX VTVT (O)': np.int64(637),
#   'Hyundai Verna 1.6 SX VTVT (O) AT': np.int64(638),
#   'Hyundai Verna 1.6 SX VTVT AT': np.int64(639),
#   'Hyundai Verna 1.6 VTVT': np.int64(640),
#   'Hyundai Verna 1.6 VTVT AT SX': np.int64(641),
#   'Hyundai Verna 1.6 VTVT EX AT': np.int64(642),
#   'Hyundai Verna 1.6 VTVT S': np.int64(643),
#   'Hyundai Verna 1.6 i ABS': np.int64(644),
#   'Hyundai Verna CRDi': np.int64(645),
#   'Hyundai Verna CRDi 1.4 E': np.int64(646),
#   'Hyundai Verna CRDi 1.6 AT SX Option': np.int64(647),
#   'Hyundai Verna CRDi 1.6 AT SX Plus': np.int64(648),
#   'Hyundai Verna CRDi 1.6 SX': np.int64(649),
#   'Hyundai Verna CRDi 1.6 SX Option': np.int64(650),
#   'Hyundai Verna CRDi ABS': np.int64(651),
#   'Hyundai Verna CRDi SX': np.int64(652),
#   'Hyundai Verna CRDi SX ABS': np.int64(653),
#   'Hyundai Verna SX CRDi AT': np.int64(654),
#   'Hyundai Verna Transform CRDi VGT SX ABS': np.int64(655),
#   'Hyundai Verna Transform SX VGT CRDi': np.int64(656),
#   'Hyundai Verna Transform SX VTVT': np.int64(657),
#   'Hyundai Verna Transform VTVT': np.int64(658),
#   'Hyundai Verna Transform Xxi ABS': np.int64(659),
#   'Hyundai Verna VTVT 1.6 AT EX': np.int64(660),
#   'Hyundai Verna VTVT 1.6 AT SX Option': np.int64(661),
#   'Hyundai Verna VTVT 1.6 AT SX Plus': np.int64(662),
#   'Hyundai Verna VTVT 1.6 SX': np.int64(663),
#   'Hyundai Verna VTVT 1.6 SX Option': np.int64(664),
#   'Hyundai Verna XXi ABS (Petrol)': np.int64(665),
#   'Hyundai Verna Xi (Petrol)': np.int64(666),
#   'Hyundai Xcent 1.1 CRDi Base': np.int64(667),
#   'Hyundai Xcent 1.1 CRDi S': np.int64(668),
#   'Hyundai Xcent 1.1 CRDi S Celebration Edition': np.int64(669),
#   'Hyundai Xcent 1.1 CRDi S Option': np.int64(670),
#   'Hyundai Xcent 1.1 CRDi SX': np.int64(671),
#   'Hyundai Xcent 1.1 CRDi SX Option': np.int64(672),
#   'Hyundai Xcent 1.2 CRDi E Plus': np.int64(673),
#   'Hyundai Xcent 1.2 CRDi S': np.int64(674),
#   'Hyundai Xcent 1.2 Kappa AT S Option': np.int64(675),
#   'Hyundai Xcent 1.2 Kappa AT SX Option': np.int64(676),
#   'Hyundai Xcent 1.2 Kappa Base': np.int64(677),
#   'Hyundai Xcent 1.2 Kappa S': np.int64(678),
#   'Hyundai Xcent 1.2 Kappa S Option': np.int64(679),
#   'Hyundai Xcent 1.2 Kappa S Option CNG': np.int64(680),
#   'Hyundai Xcent 1.2 Kappa SX': np.int64(681),
#   'Hyundai Xcent 1.2 Kappa SX Option': np.int64(682),
#   'Hyundai Xcent 1.2 VTVT E': np.int64(683),
#   'Hyundai Xcent 1.2 VTVT E Plus': np.int64(684),
#   'Hyundai Xcent 1.2 VTVT S': np.int64(685),
#   'Hyundai Xcent 1.2 VTVT SX': np.int64(686),
#   'Hyundai i10 Asta': np.int64(687),
#   'Hyundai i10 Asta 1.2 AT with Sunroof': np.int64(688),
#   'Hyundai i10 Asta AT': np.int64(689),
#   'Hyundai i10 Asta Sunroof AT': np.int64(690),
#   'Hyundai i10 Era': np.int64(691),
#   'Hyundai i10 Era 1.1': np.int64(692),
#   'Hyundai i10 Era 1.1 iTech SE': np.int64(693),
#   'Hyundai i10 Magna': np.int64(694),
#   'Hyundai i10 Magna 1.1': np.int64(695),
#   'Hyundai i10 Magna 1.1 iTech SE': np.int64(696),
#   'Hyundai i10 Magna 1.1L': np.int64(697),
#   'Hyundai i10 Magna 1.2': np.int64(698),
#   'Hyundai i10 Magna 1.2 iTech SE': np.int64(699),
#   'Hyundai i10 Magna AT': np.int64(700),
#   'Hyundai i10 Magna LPG': np.int64(701),
#   'Hyundai i10 Magna Optional 1.1L': np.int64(702),
#   'Hyundai i10 Magna(O) with Sun Roof': np.int64(703),
#   'Hyundai i10 Sportz': np.int64(704),
#   'Hyundai i10 Sportz 1.1L': np.int64(705),
#   'Hyundai i10 Sportz 1.2': np.int64(706),
#   'Hyundai i10 Sportz 1.2 AT': np.int64(707),
#   'Hyundai i10 Sportz AT': np.int64(708),
#   'Hyundai i10 Sportz Option': np.int64(709),
#   'Hyundai i20 1.2 Asta': np.int64(710),
#   'Hyundai i20 1.2 Asta Option': np.int64(711),
#   'Hyundai i20 1.2 Asta with AVN': np.int64(712),
#   'Hyundai i20 1.2 Era': np.int64(713),
#   'Hyundai i20 1.2 Magna': np.int64(714),
#   'Hyundai i20 1.2 Magna Executive': np.int64(715),
#   'Hyundai i20 1.2 Sportz': np.int64(716),
#   'Hyundai i20 1.2 Sportz Option': np.int64(717),
#   'Hyundai i20 1.2 Spotz': np.int64(718),
#   'Hyundai i20 1.4 Asta': np.int64(719),
#   'Hyundai i20 1.4 Asta (AT)': np.int64(720),
#   'Hyundai i20 1.4 Asta CRDi with AVN': np.int64(721),
#   'Hyundai i20 1.4 Asta Option': np.int64(722),
#   'Hyundai i20 1.4 Asta Optional With Sunroof': np.int64(723),
#   'Hyundai i20 1.4 CRDi Asta': np.int64(724),
#   'Hyundai i20 1.4 CRDi Magna': np.int64(725),
#   'Hyundai i20 1.4 CRDi Sportz': np.int64(726),
#   'Hyundai i20 1.4 Magna ABS': np.int64(727),
#   'Hyundai i20 1.4 Sportz': np.int64(728),
#   'Hyundai i20 2015-2017 1.2 Asta': np.int64(729),
#   'Hyundai i20 2015-2017 1.2 Asta with AVN': np.int64(730),
#   'Hyundai i20 2015-2017 1.2 Magna': np.int64(731),
#   'Hyundai i20 2015-2017 1.4 Magna ABS': np.int64(732),
#   'Hyundai i20 2015-2017 Asta': np.int64(733),
#   'Hyundai i20 2015-2017 Asta 1.2': np.int64(734),
#   'Hyundai i20 2015-2017 Magna': np.int64(735),
#   'Hyundai i20 2015-2017 Magna 1.2': np.int64(736),
#   'Hyundai i20 2015-2017 Sportz 1.2': np.int64(737),
#   'Hyundai i20 2015-2017 Sportz AT 1.4': np.int64(738),
#   'Hyundai i20 Active 1.2 S': np.int64(739),
#   'Hyundai i20 Active 1.2 SX': np.int64(740),
#   'Hyundai i20 Active 1.2 SX Dual Tone': np.int64(741),
#   'Hyundai i20 Active 1.4 SX': np.int64(742),
#   'Hyundai i20 Active 1.4 SX Dual Tone': np.int64(743),
#   'Hyundai i20 Active S Diesel': np.int64(744),
#   'Hyundai i20 Active SX Dual Tone Petrol': np.int64(745),
#   'Hyundai i20 Active SX Petrol': np.int64(746),
#   'Hyundai i20 Asta': np.int64(747),
#   'Hyundai i20 Asta (o)': np.int64(748),
#   'Hyundai i20 Asta (o) 1.4 CRDi (Diesel)': np.int64(749),
#   'Hyundai i20 Asta 1.2': np.int64(750),
#   'Hyundai i20 Asta 1.4 CRDi': np.int64(751),
#   'Hyundai i20 Asta 1.4 CRDi (Diesel)': np.int64(752),
#   'Hyundai i20 Asta Option 1.2': np.int64(753),
#   'Hyundai i20 Asta Option 1.4 CRDi': np.int64(754),
#   'Hyundai i20 Asta Optional with Sunroof 1.2': np.int64(755),
#   'Hyundai i20 Diesel Asta Option': np.int64(756),
#   'Hyundai i20 Era 1.4 CRDi': np.int64(757),
#   'Hyundai i20 Magna': np.int64(758),
#   'Hyundai i20 Magna 1.2': np.int64(759),
#   'Hyundai i20 Magna 1.4 CRDi': np.int64(760),
#   'Hyundai i20 Magna 1.4 CRDi (Diesel)': np.int64(761),
#   'Hyundai i20 Magna Optional 1.2': np.int64(762),
#   'Hyundai i20 Magna Optional 1.4 CRDi': np.int64(763),
#   'Hyundai i20 Sportz 1.2': np.int64(764),
#   'Hyundai i20 Sportz 1.4 CRDi': np.int64(765),
#   'Hyundai i20 Sportz AT 1.4': np.int64(766),
#   'Hyundai i20 Sportz Diesel': np.int64(767),
#   'Hyundai i20 Sportz Option': np.int64(768),
#   'Hyundai i20 Sportz Option 1.2': np.int64(769),
#   'Hyundai i20 Sportz Option Diesel': np.int64(770),
#   'Hyundai i20 Sportz Petrol': np.int64(771),
#   'ISUZU D-MAX V-Cross 4X4': np.int64(772),
#   'Isuzu MUX 4WD': np.int64(773),
#   'Jaguar F Type 5.0 V8 S': np.int64(774),
#   'Jaguar XE 2.0L Diesel Prestige': np.int64(775),
#   'Jaguar XE Portfolio': np.int64(776),
#   'Jaguar XF 2.0 Diesel Portfolio': np.int64(777),
#   'Jaguar XF 2.2 Litre Executive': np.int64(778),
#   'Jaguar XF 2.2 Litre Luxury': np.int64(779),
#   'Jaguar XF 3.0 Litre S Premium Luxury': np.int64(780),
#   'Jaguar XF Aero Sport Edition': np.int64(781),
#   'Jaguar XF Diesel': np.int64(782),
#   'Jaguar XJ 2.0L Portfolio': np.int64(783),
#   'Jaguar XJ 3.0L Portfolio': np.int64(784),
#   'Jaguar XJ 3.0L Portfolio LWB': np.int64(785),
#   'Jaguar XJ 3.0L Premium Luxury': np.int64(786),
#   'Jaguar XJ 5.0 L V8 Supercharged': np.int64(787),
#   'Jeep Compass 1.4 Limited Option': np.int64(788),
#   'Jeep Compass 2.0 Limited': np.int64(789),
#   'Jeep Compass 2.0 Limited 4X4': np.int64(790),
#   'Jeep Compass 2.0 Limited Option 4X4': np.int64(791),
#   'Jeep Compass 2.0 Limited Option Black': np.int64(792),
#   'Jeep Compass 2.0 Longitude': np.int64(793),
#   'Jeep Compass 2.0 Sport': np.int64(794),
#   'Lamborghini Gallardo Coupe': np.int64(795),
#   'Land Rover Discovery 3 TDV6 Diesel Automatic': np.int64(796),
#   'Land Rover Discovery 4 TDV6 SE': np.int64(797),
#   'Land Rover Discovery HSE Luxury 3.0 TD6': np.int64(798),
#   'Land Rover Discovery SE 3.0 TD6': np.int64(799),
#   'Land Rover Discovery Sport SD4 HSE Luxury': np.int64(800),
#   'Land Rover Discovery Sport SD4 HSE Luxury 7S': np.int64(801),
#   'Land Rover Discovery Sport TD4 HSE': np.int64(802),
#   'Land Rover Discovery Sport TD4 HSE 7S': np.int64(803),
#   'Land Rover Discovery Sport TD4 S': np.int64(804),
#   'Land Rover Freelander 2 HSE': np.int64(805),
#   'Land Rover Freelander 2 HSE SD4': np.int64(806),
#   'Land Rover Freelander 2 SE': np.int64(807),
#   'Land Rover Freelander 2 TD4 HSE': np.int64(808),
#   'Land Rover Freelander 2 TD4 S': np.int64(809),
#   'Land Rover Freelander 2 TD4 SE': np.int64(810),
#   'Land Rover Range Rover 2.2L Dynamic': np.int64(811),
#   'Land Rover Range Rover 2.2L Prestige': np.int64(812),
#   'Land Rover Range Rover 2.2L Pure': np.int64(813),
#   'Land Rover Range Rover 3.0 D': np.int64(814),
#   'Land Rover Range Rover 3.0 Diesel LWB Vogue': np.int64(815),
#   'Land Rover Range Rover 3.6 TDV8 Vogue SE': np.int64(816),
#   'Land Rover Range Rover 3.6 TDV8 Vogue SE Diesel': np.int64(817),
#   'Land Rover Range Rover Evoque 2.0 TD4 HSE Dynamic': np.int64(818),
#   'Land Rover Range Rover Evoque 2.0 TD4 Pure': np.int64(819),
#   'Land Rover Range Rover HSE Dynamic': np.int64(820),
#   'Land Rover Range Rover Sport 2005 2012 HSE': np.int64(821),
#   'Land Rover Range Rover Sport 2005 2012 Sport': np.int64(822),
#   'Land Rover Range Rover Sport HSE': np.int64(823),
#   'Land Rover Range Rover Sport SE': np.int64(824),
#   'Land Rover Range Rover TDV8 (Diesel)': np.int64(825),
#   'Land Rover Range Rover Vogue SE 4.4 SDV8': np.int64(826),
#   'Mahindra Bolero DI BSII': np.int64(827),
#   'Mahindra Bolero SLE': np.int64(828),
#   'Mahindra Bolero SLE BSIII': np.int64(829),
#   'Mahindra Bolero SLX 2WD': np.int64(830),
#   'Mahindra Bolero VLX BS IV': np.int64(831),
#   'Mahindra Bolero VLX CRDe': np.int64(832),
#   'Mahindra Bolero ZLX': np.int64(833),
#   'Mahindra Bolero ZLX BSIII': np.int64(834),
#   'Mahindra Bolero mHAWK D70 ZLX': np.int64(835),
#   'Mahindra E Verito D4': np.int64(836),
#   'Mahindra Jeep MM 540 DP': np.int64(837),
#   'Mahindra Jeep MM 550 PE': np.int64(838),
#   'Mahindra KUV 100 G80 K6 Plus 5Str': np.int64(839),
#   'Mahindra KUV 100 G80 K8': np.int64(840),
#   'Mahindra KUV 100 G80 K8 Dual Tone': np.int64(841),
#   'Mahindra KUV 100 mFALCON D75 K4': np.int64(842),
#   'Mahindra KUV 100 mFALCON D75 K4 Plus': np.int64(843),
#   'Mahindra KUV 100 mFALCON D75 K4 Plus 5str': np.int64(844),
#   'Mahindra KUV 100 mFALCON D75 K6': np.int64(845),
#   'Mahindra KUV 100 mFALCON D75 K8': np.int64(846),
#   'Mahindra KUV 100 mFALCON D75 K8 Dual Tone': np.int64(847),
#   'Mahindra KUV 100 mFALCON G80 K2': np.int64(848),
#   'Mahindra KUV 100 mFALCON G80 K6 5str AW': np.int64(849),
#   'Mahindra KUV 100 mFALCON G80 K6 Plus': np.int64(850),
#   'Mahindra KUV 100 mFALCON G80 K8': np.int64(851),
#   'Mahindra Logan Diesel 1.5 DLS': np.int64(852),
#   'Mahindra Logan Petrol 1.4 GLE': np.int64(853),
#   'Mahindra NuvoSport N6': np.int64(854),
#   'Mahindra NuvoSport N8': np.int64(855),
#   'Mahindra Quanto C2': np.int64(856),
#   'Mahindra Quanto C4': np.int64(857),
#   'Mahindra Quanto C6': np.int64(858),
#   'Mahindra Quanto C8': np.int64(859),
#   'Mahindra Renault Logan 1.4 GLX Petrol': np.int64(860),
#   'Mahindra Renault Logan 1.5 DLE Diesel': np.int64(861),
#   'Mahindra Scorpio 1.99 S10': np.int64(862),
#   'Mahindra Scorpio 1.99 S10 4WD': np.int64(863),
#   'Mahindra Scorpio 1.99 S4 Plus': np.int64(864),
#   'Mahindra Scorpio 1.99 S8': np.int64(865),
#   'Mahindra Scorpio 2.6 CRDe': np.int64(866),
#   'Mahindra Scorpio 2.6 DX': np.int64(867),
#   'Mahindra Scorpio 2.6 LX': np.int64(868),
#   'Mahindra Scorpio 2.6 SLX CRDe': np.int64(869),
#   'Mahindra Scorpio 2009-2014 LX 2WD 7S': np.int64(870),
#   'Mahindra Scorpio 2009-2014 SLE 7S BSIV': np.int64(871),
#   'Mahindra Scorpio 2009-2014 VLX 2WD 7S BSIV': np.int64(872),
#   'Mahindra Scorpio 2009-2014 VLX 4WD AT 7S BSIV': np.int64(873),
#   'Mahindra Scorpio DX 2.6 Turbo 8 Str': np.int64(874),
#   'Mahindra Scorpio LX 2.6 Turbo': np.int64(875),
#   'Mahindra Scorpio LX BS IV': np.int64(876),
#   'Mahindra Scorpio S10 4WD': np.int64(877),
#   'Mahindra Scorpio S10 7 Seater': np.int64(878),
#   'Mahindra Scorpio S10 AT 4WD': np.int64(879),
#   'Mahindra Scorpio S2 7 Seater': np.int64(880),
#   'Mahindra Scorpio S4 7 Seater': np.int64(881),
#   'Mahindra Scorpio S4 Plus': np.int64(882),
#   'Mahindra Scorpio S6 7 Seater': np.int64(883),
#   'Mahindra Scorpio S6 Plus 7 Seater': np.int64(884),
#   'Mahindra Scorpio S8 8 Seater': np.int64(885),
#   'Mahindra Scorpio SLE BSIII': np.int64(886),
#   'Mahindra Scorpio SLE BSIV': np.int64(887),
#   'Mahindra Scorpio SLX': np.int64(888),
#   'Mahindra Scorpio VLX': np.int64(889),
#   'Mahindra Scorpio VLX 2.2 mHawk Airbag BSIV': np.int64(890),
#   'Mahindra Scorpio VLX 2.2 mHawk BSIII': np.int64(891),
#   'Mahindra Scorpio VLX 2WD AIRBAG BSIV': np.int64(892),
#   'Mahindra Scorpio VLX 2WD AT BSIV': np.int64(893),
#   'Mahindra Scorpio VLX 2WD Airbag BSIII': np.int64(894),
#   'Mahindra Scorpio VLX 2WD BSIV': np.int64(895),
#   'Mahindra Scorpio VLX 4WD': np.int64(896),
#   'Mahindra Scorpio VLX 4WD AIRBAG AT BSIV': np.int64(897),
#   'Mahindra Scorpio VLX 4WD AIRBAG BSIV': np.int64(898),
#   'Mahindra Scorpio VLX AT AIRBAG BSIV': np.int64(899),
#   'Mahindra Ssangyong Rexton RX5': np.int64(900),
#   'Mahindra Ssangyong Rexton RX7': np.int64(901),
#   'Mahindra TUV 300 2015-2019 T8': np.int64(902),
#   'Mahindra TUV 300 2015-2019 mHAWK100 T8': np.int64(903),
#   'Mahindra TUV 300 2015-2019 mHAWK100 T8 AMT': np.int64(904),
#   'Mahindra TUV 300 T8': np.int64(905),
#   'Mahindra TUV 300 T8 AMT': np.int64(906),
#   'Mahindra Thar CRDe': np.int64(907),
#   'Mahindra Thar CRDe AC': np.int64(908),
#   'Mahindra Thar DI 4X4': np.int64(909),
#   'Mahindra Verito 1.5 D4 BSIV': np.int64(910),
#   'Mahindra Verito 1.5 D6 BSIV': np.int64(911),
#   'Mahindra XUV300 W8 Diesel': np.int64(912),
#   'Mahindra XUV500 AT W10 AWD': np.int64(913),
#   'Mahindra XUV500 AT W10 FWD': np.int64(914),
#   'Mahindra XUV500 AT W8 FWD': np.int64(915),
#   'Mahindra XUV500 W10 1.99 mHawk': np.int64(916),
#   'Mahindra XUV500 W10 2WD': np.int64(917),
#   'Mahindra XUV500 W10 AWD': np.int64(918),
#   'Mahindra XUV500 W4': np.int64(919),
#   'Mahindra XUV500 W4 1.99 mHawk': np.int64(920),
#   'Mahindra XUV500 W6 2WD': np.int64(921),
#   'Mahindra XUV500 W7': np.int64(922),
#   'Mahindra XUV500 W8 1.99 mHawk': np.int64(923),
#   'Mahindra XUV500 W8 2WD': np.int64(924),
#   'Mahindra XUV500 W8 4WD': np.int64(925),
#   'Mahindra XUV500 W9 AT': np.int64(926),
#   'Mahindra Xylo D2 BS III': np.int64(927),
#   'Mahindra Xylo D2 BSIV': np.int64(928),
#   'Mahindra Xylo D2 Maxx': np.int64(929),
#   'Mahindra Xylo D4': np.int64(930),
#   'Mahindra Xylo D4 BS III': np.int64(931),
#   'Mahindra Xylo D4 BSIV': np.int64(932),
#   'Mahindra Xylo E2': np.int64(933),
#   'Mahindra Xylo E4': np.int64(934),
#   'Mahindra Xylo E4 ABS BS III': np.int64(935),
#   'Mahindra Xylo E8': np.int64(936),
#   'Mahindra Xylo E8 ABS BS IV': np.int64(937),
#   'Mahindra Xylo E8 BS IV': np.int64(938),
#   'Mahindra Xylo H4': np.int64(939),
#   'Maruti 1000 AC': np.int64(940),
#   'Maruti 800 AC': np.int64(941),
#   'Maruti 800 AC BSIII': np.int64(942),
#   'Maruti 800 AC Uniq': np.int64(943),
#   'Maruti 800 DX BSII': np.int64(944),
#   'Maruti 800 Std': np.int64(945),
#   'Maruti 800 Std BSIII': np.int64(946),
#   'Maruti A-Star AT VXI': np.int64(947),
#   'Maruti A-Star AT Vxi Aktiv': np.int64(948),
#   'Maruti A-Star Lxi': np.int64(949),
#   'Maruti A-Star Vxi': np.int64(950),
#   'Maruti Alto 800 2016-2019 CNG LXI': np.int64(951),
#   'Maruti Alto 800 2016-2019 LXI': np.int64(952),
#   'Maruti Alto 800 2016-2019 LXI Optional': np.int64(953),
#   'Maruti Alto 800 2016-2019 VXI': np.int64(954),
#   'Maruti Alto 800 CNG LXI': np.int64(955),
#   'Maruti Alto 800 LXI': np.int64(956),
#   'Maruti Alto 800 LXI Airbag': np.int64(957),
#   'Maruti Alto 800 VXI': np.int64(958),
#   'Maruti Alto Green LXi (CNG)': np.int64(959),
#   'Maruti Alto K10 2010-2014 VXI': np.int64(960),
#   'Maruti Alto K10 LXI': np.int64(961),
#   'Maruti Alto K10 LXI CNG': np.int64(962),
#   'Maruti Alto K10 LXI CNG Optional': np.int64(963),
#   'Maruti Alto K10 LXI Optional': np.int64(964),
#   'Maruti Alto K10 VXI': np.int64(965),
#   'Maruti Alto K10 VXI AGS': np.int64(966),
#   'Maruti Alto LX': np.int64(967),
#   'Maruti Alto LX BSIII': np.int64(968),
#   'Maruti Alto LXI': np.int64(969),
#   'Maruti Alto LXi': np.int64(970),
#   'Maruti Alto LXi BSII': np.int64(971),
#   'Maruti Alto LXi BSIII': np.int64(972),
#   'Maruti Alto Std': np.int64(973),
#   'Maruti Alto VXi': np.int64(974),
#   'Maruti Alto Vxi 1.1': np.int64(975),
#   'Maruti Baleno Alpha': np.int64(976),
#   'Maruti Baleno Alpha 1.2': np.int64(977),
#   'Maruti Baleno Alpha 1.3': np.int64(978),
#   'Maruti Baleno Alpha Automatic': np.int64(979),
#   'Maruti Baleno Alpha CVT': np.int64(980),
#   'Maruti Baleno Alpha Diesel': np.int64(981),
#   'Maruti Baleno Delta': np.int64(982),
#   'Maruti Baleno Delta 1.2': np.int64(983),
#   'Maruti Baleno Delta 1.3': np.int64(984),
#   'Maruti Baleno Delta Automatic': np.int64(985),
#   'Maruti Baleno Delta CVT': np.int64(986),
#   'Maruti Baleno LXI': np.int64(987),
#   'Maruti Baleno LXI - BSIII': np.int64(988),
#   'Maruti Baleno RS 1.0 Petrol': np.int64(989),
#   'Maruti Baleno RS Petrol': np.int64(990),
#   'Maruti Baleno Sigma 1.2': np.int64(991),
#   'Maruti Baleno Vxi': np.int64(992),
#   'Maruti Baleno Vxi - BSIII': np.int64(993),
#   'Maruti Baleno Zeta': np.int64(994),
#   'Maruti Baleno Zeta 1.2': np.int64(995),
#   'Maruti Baleno Zeta 1.3': np.int64(996),
#   'Maruti Baleno Zeta Automatic': np.int64(997),
#   'Maruti Baleno Zeta CVT': np.int64(998),
#   'Maruti Celerio CNG VXI MT': np.int64(999),
#   ...},
#  'Location': {'Ahmedabad': np.int64(0),
#   'Bangalore': np.int64(1),
#   'Chennai': np.int64(2),
#   'Coimbatore': np.int64(3),
#   'Delhi': np.int64(4),
#   'Hyderabad': np.int64(5),
#   'Jaipur': np.int64(6),
#   'Kochi': np.int64(7),
#   'Kolkata': np.int64(8),
#   'Mumbai': np.int64(9),
#   'Pune': np.int64(10)},
#  'Fuel_Type': {'CNG': np.int64(0),
#   'Diesel': np.int64(1),
#   'Electric': np.int64(2),
#   'LPG': np.int64(3),
#   'Petrol': np.int64(4)},
#  'Transmission': {'Automatic': np.int64(0), 'Manual': np.int64(1)},
#  'Owner_Type': {'First': np.int64(0),
#   'Fourth & Above': np.int64(1),
#   'Second': np.int64(2),
#   'Third': np.int64(3)}}

# %%
df
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     1200         9  2010              72000          0             1
# 1      512        10  2015              41000          1             1
# 2      486         2  2011              46000          4             1
# 3     1059         2  2012              87000          1             1
# 4       23         3  2013              40670          1             0
# ...    ...       ...   ...                ...        ...           ...
# 6014  1159         4  2014              27365          1             1
# 6015   668         6  2015             100000          1             1
# 6016   932         6  2012              55000          1             1
# 6017  1207         8  2013              46000          4             1
# 6018   165         5  2011              47000          1             1
#
#       Owner_Type  Mileage  Engine   Power  Seats  Price
# 0              0    26.60   998.0   58.16    5.0   1.75
# 1              0    19.67  1582.0  126.20    5.0  12.50
# 2              0    18.20  1199.0   88.70    5.0   4.50
# 3              0    20.77  1248.0   88.76    7.0   6.00
# 4              2    15.20  1968.0  140.80    5.0  17.74
# ...          ...      ...     ...     ...    ...    ...
# 6014           0    28.40  1248.0   74.00    5.0   4.75
# 6015           0    24.40  1120.0   71.00    5.0   4.00
# 6016           2    14.00  2498.0  112.00    8.0   2.90
# 6017           0    18.90   998.0   67.10    5.0   2.65
# 6018           0    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %%
le.classes_
# Out:
# array(['First', 'Fourth & Above', 'Second', 'Third'], dtype=object)

# %%
le.transform(le.classes_)
# Out:
# array([0, 1, 2, 3])

# %%
df_rm = df.copy()

# %%
cat_cols
# Out:
# ['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type']

# %%
for col in cat_cols:
  reverse_mapping = {v : k for k, v in label_mappings[col].items()}
  df_rm[col] = df[col].map(reverse_mapping)

# %% [markdown]
# # Skewness and Kurtosis

# %% [markdown]
# Skewness = 0	-- Perfectly symmetrical (e.g., normal distribution)
#
#
# Skewness > 0	-- Right-skewed (longer tail on the right; more smaller values)
#
# Skewness < 0	-- Left-skewed (longer tail on the left; more larger values)

# %% [markdown]
# Kurtosis ≈ 3	-- Mesokurtic – Normal distribution (benchmark)
#
# Kurtosis > 3	-- Leptokurtic – Heavy tails, sharp peak (more outliers)
#
# Kurtosis < 3	-- Platykurtic – Light tails, flat peak (fewer outliers)

# %%
df
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     1200         9  2010              72000          0             1
# 1      512        10  2015              41000          1             1
# 2      486         2  2011              46000          4             1
# 3     1059         2  2012              87000          1             1
# 4       23         3  2013              40670          1             0
# ...    ...       ...   ...                ...        ...           ...
# 6014  1159         4  2014              27365          1             1
# 6015   668         6  2015             100000          1             1
# 6016   932         6  2012              55000          1             1
# 6017  1207         8  2013              46000          4             1
# 6018   165         5  2011              47000          1             1
#
#       Owner_Type  Mileage  Engine   Power  Seats  Price
# 0              0    26.60   998.0   58.16    5.0   1.75
# 1              0    19.67  1582.0  126.20    5.0  12.50
# 2              0    18.20  1199.0   88.70    5.0   4.50
# 3              0    20.77  1248.0   88.76    7.0   6.00
# 4              2    15.20  1968.0  140.80    5.0  17.74
# ...          ...      ...     ...     ...    ...    ...
# 6014           0    28.40  1248.0   74.00    5.0   4.75
# 6015           0    24.40  1120.0   71.00    5.0   4.00
# 6016           2    14.00  2498.0  112.00    8.0   2.90
# 6017           0    18.90   998.0   67.10    5.0   2.65
# 6018           0    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %%
df.skew()
# Out:
# Name                  0.113310
# Location             -0.133257
# Year                 -0.845802
# Kilometers_Driven    58.724662
# Fuel_Type             0.155741
# Transmission         -0.948662
# Owner_Type            1.784496
# Mileage              -0.431814
# Engine                1.425742
# Power                 1.939649
# Seats                 1.842228
# Price                 3.335232
# dtype: float64

# %%
df.kurt()
# Out:
# Name                   -1.064229
# Location               -1.134715
# Year                    0.894201
# Kilometers_Driven    4125.094109
# Fuel_Type              -1.946701
# Transmission           -1.100406
# Owner_Type              1.486772
# Mileage                 1.670613
# Engine                  3.147448
# Power                   6.741692
# Seats                   4.586277
# Price                  17.092202
# dtype: float64

# %% [markdown]
# To remove skewness and kurtosis we do log transform

# %%
for i in df.columns:
  df[i] = np.log1p(df[i])

# %%
df.skew()
# Out:
# Name                -1.893502
# Location            -1.154414
# Year                -0.851119
# Kilometers_Driven   -1.290209
# Fuel_Type            0.080443
# Transmission        -0.948662
# Owner_Type           1.693431
# Mileage             -4.981765
# Engine               0.295886
# Power                0.446981
# Seats                0.452887
# Price                0.754372
# dtype: float64

# %%
df.kurt()
# Out:
# Name                  4.544600
# Location              0.957486
# Year                  0.910624
# Kilometers_Driven     4.705521
# Fuel_Type            -1.764025
# Transmission         -1.100406
# Owner_Type            0.942195
# Mileage              35.484741
# Engine                0.983472
# Power                 0.173541
# Seats                14.415136
# Price                 0.310180
# dtype: float64

# %% [markdown]
# # Scaling

# %%
df
# Out:
#           Name  Location      Year  Kilometers_Driven  Fuel_Type  \
# 0     7.090910  2.302585  7.606387          11.184435   0.000000
# 1     6.240276  2.397895  7.608871          10.621352   0.693147
# 2     6.188264  1.098612  7.606885          10.736418   1.609438
# 3     6.966024  1.098612  7.607381          11.373675   0.693147
# 4     3.178054  1.386294  7.607878          10.613271   0.693147
# ...        ...       ...       ...                ...        ...
# 6014  7.056175  1.609438  7.608374          10.217057   0.693147
# 6015  6.505784  1.945910  7.608871          11.512935   0.693147
# 6016  6.838405  1.945910  7.607381          10.915107   0.693147
# 6017  7.096721  2.197225  7.607878          10.736418   1.609438
# 6018  5.111988  1.791759  7.606885          10.757924   0.693147
#
#       Transmission  Owner_Type   Mileage    Engine     Power     Seats  \
# 0         0.693147    0.000000  3.317816  6.906755  4.080246  1.791759
# 1         0.693147    0.000000  3.028683  7.367077  4.845761  1.791759
# 2         0.693147    0.000000  2.954910  7.090077  4.496471  1.791759
# 3         0.693147    0.000000  3.080533  7.130099  4.497139  2.079442
# 4         0.000000    1.098612  2.785011  7.585281  4.954418  1.791759
# ...            ...         ...       ...       ...       ...       ...
# 6014      0.693147    0.000000  3.380995  7.130099  4.317488  1.791759
# 6015      0.693147    0.000000  3.234749  7.021976  4.276666  1.791759
# 6016      0.693147    1.098612  2.708050  7.823646  4.727388  2.197225
# 6017      0.693147    0.000000  2.990720  6.906755  4.220977  1.791759
# 6018      0.693147    0.000000  3.274878  6.842683  4.070735  1.791759
#
#          Price
# 0     1.011601
# 1     2.602690
# 2     1.704748
# 3     1.945910
# 4     2.930660
# ...        ...
# 6014  1.749200
# 6015  1.609438
# 6016  1.360977
# 6017  1.294727
# 6018  1.252763
#
# [6019 rows x 12 columns]

# %%
len(df.columns)
# Out:
# 12

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
ss = StandardScaler()    # -1 to 1

# %%
ms = MinMaxScaler()      # 0 to 1

# %%
df_scaled = ms.fit_transform(df)

# %%
df_scaled = ss.fit_transform(df)

# %%
df_scaled
# Out:
# array([[ 0.58059544,  0.93719338, -1.0264747 , ..., -1.39754769,
#         -0.31625926, -1.34573971],
#        [-0.2900926 ,  1.09902756,  0.50242201, ...,  0.4797557 ,
#         -0.31625926,  0.78093157],
#        [-0.34333052, -1.10712083, -0.72039148, ..., -0.37682199,
#         -0.31625926, -0.4192696 ],
#        ...,
#        [ 0.32213792,  0.33156869, -0.41446035, ...,  0.18946522,
#          3.06085197, -0.87875939],
#        [ 0.58654401,  0.75829399, -0.10868115, ..., -1.05242596,
#         -0.31625926, -0.96730924],
#        [-1.44498053,  0.06982488, -0.72039148, ..., -1.42087176,
#         -0.31625926, -1.02339917]])

# %%
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# %%
df_scaled
# Out:
#           Name  Location      Year  Kilometers_Driven  Fuel_Type  \
# 0     0.580595  0.937193 -1.026475           0.594714  -2.369367
# 1    -0.290093  1.099028  0.502422          -0.192070  -0.884471
# 2    -0.343331 -1.107121 -0.720391          -0.031290   1.078456
# 3     0.452766 -1.107121 -0.414460           0.859135  -0.884471
# 4    -3.424508 -0.618644 -0.108681          -0.203362  -0.884471
# ...        ...       ...       ...                ...        ...
# 6014  0.545042 -0.239752  0.196946          -0.756983  -0.884471
# 6015 -0.018325  0.331569  0.502422           1.053720  -0.884471
# 6016  0.322138  0.331569 -0.414460           0.218387  -0.884471
# 6017  0.586544  0.758294 -0.108681          -0.031290   1.078456
# 6018 -1.444981  0.069825 -0.720391          -0.001241  -0.884471
#
#       Transmission  Owner_Type   Mileage    Engine     Power     Seats  \
# 0         0.632529   -0.468174  1.083113 -1.254005 -1.397548 -0.316259
# 1         0.632529   -0.468174  0.324445  0.103719  0.479756 -0.316259
# 2         0.632529   -0.468174  0.130869 -0.713295 -0.376822 -0.316259
# 3         0.632529   -0.468174  0.460496 -0.595251 -0.375182  2.079839
# 4        -1.580955    2.056255 -0.314937  0.747313  0.746220 -0.316259
# ...            ...         ...       ...       ...       ...       ...
# 6014      0.632529   -0.468174  1.248891 -0.595251 -0.815748 -0.316259
# 6015      0.632529   -0.468174  0.865151 -0.914158 -0.915858 -0.316259
# 6016      0.632529    2.056255 -0.516879  1.450372  0.189465  3.060852
# 6017      0.632529   -0.468174  0.224831 -1.254005 -1.052426 -0.316259
# 6018      0.632529   -0.468174  0.970447 -1.442984 -1.420872 -0.316259
#
#          Price
# 0    -1.345740
# 1     0.780932
# 2    -0.419270
# 3    -0.096929
# 4     1.219302
# ...        ...
# 6014 -0.359855
# 6015 -0.546663
# 6016 -0.878759
# 6017 -0.967309
# 6018 -1.023399
#
# [6019 rows x 12 columns]

# %% [markdown]
# # Removing Outliers

# %%
def remove_outliers(df, column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR =  Q3-Q1
  lower_bound = Q1-1.5*IQR
  upper_bound = Q3+1.5*IQR

  return df[(df[column] >= lower_bound) & (df[column] <=upper_bound)]

# %%
df_rm = remove_outliers(df_rm, "Kilometers_Driven")

# %% [markdown]
# # Visualization

# %%
df_scaled
# Out:
#           Name  Location      Year  Kilometers_Driven  Fuel_Type  \
# 0     0.580595  0.937193 -1.026475           0.594714  -2.369367
# 1    -0.290093  1.099028  0.502422          -0.192070  -0.884471
# 2    -0.343331 -1.107121 -0.720391          -0.031290   1.078456
# 3     0.452766 -1.107121 -0.414460           0.859135  -0.884471
# 4    -3.424508 -0.618644 -0.108681          -0.203362  -0.884471
# ...        ...       ...       ...                ...        ...
# 6014  0.545042 -0.239752  0.196946          -0.756983  -0.884471
# 6015 -0.018325  0.331569  0.502422           1.053720  -0.884471
# 6016  0.322138  0.331569 -0.414460           0.218387  -0.884471
# 6017  0.586544  0.758294 -0.108681          -0.031290   1.078456
# 6018 -1.444981  0.069825 -0.720391          -0.001241  -0.884471
#
#       Transmission  Owner_Type   Mileage    Engine     Power     Seats  \
# 0         0.632529   -0.468174  1.083113 -1.254005 -1.397548 -0.316259
# 1         0.632529   -0.468174  0.324445  0.103719  0.479756 -0.316259
# 2         0.632529   -0.468174  0.130869 -0.713295 -0.376822 -0.316259
# 3         0.632529   -0.468174  0.460496 -0.595251 -0.375182  2.079839
# 4        -1.580955    2.056255 -0.314937  0.747313  0.746220 -0.316259
# ...            ...         ...       ...       ...       ...       ...
# 6014      0.632529   -0.468174  1.248891 -0.595251 -0.815748 -0.316259
# 6015      0.632529   -0.468174  0.865151 -0.914158 -0.915858 -0.316259
# 6016      0.632529    2.056255 -0.516879  1.450372  0.189465  3.060852
# 6017      0.632529   -0.468174  0.224831 -1.254005 -1.052426 -0.316259
# 6018      0.632529   -0.468174  0.970447 -1.442984 -1.420872 -0.316259
#
#          Price
# 0    -1.345740
# 1     0.780932
# 2    -0.419270
# 3    -0.096929
# 4     1.219302
# ...        ...
# 6014 -0.359855
# 6015 -0.546663
# 6016 -0.878759
# 6017 -0.967309
# 6018 -1.023399
#
# [6019 rows x 12 columns]

# %% [markdown]
# 1.   matplotlib
# 2.   seaborn
# 3.   pandas_plotting
# 4.   plotly

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                        Name  Location      Year  Kilometers_Driven  Fuel_Type  \
# Name               1.000000  0.048346  0.024943           0.024903   0.065119
# Location           0.048346  1.000000  0.005977          -0.090321   0.095720
# Year               0.024943  0.005977  1.000000          -0.497760  -0.129410
# Kilometers_Driven  0.024903 -0.090321 -0.497760           1.000000  -0.247554
# Fuel_Type          0.065119  0.095720 -0.129410          -0.247554   1.000000
# Transmission       0.305898  0.040216 -0.097057           0.101835   0.118477
# Owner_Type        -0.035280 -0.061135 -0.381076           0.216202   0.040018
# Mileage            0.033332  0.032652  0.279785          -0.110177  -0.097997
# Engine            -0.165263 -0.067854 -0.045228           0.173399  -0.428913
# Power             -0.299289 -0.061368  0.029378           0.049946  -0.288380
# Seats              0.121723 -0.031139  0.016978           0.192039  -0.285367
# Price             -0.239868 -0.115545  0.473132          -0.200195  -0.396625
#
#                    Transmission  Owner_Type   Mileage    Engine     Power  \
# Name                   0.305898   -0.035280  0.033332 -0.165263 -0.299289
# Location               0.040216   -0.061135  0.032652 -0.067854 -0.061368
# Year                  -0.097057   -0.381076  0.279785 -0.045228  0.029378
# Kilometers_Driven      0.101835    0.216202 -0.110177  0.173399  0.049946
# Fuel_Type              0.118477    0.040018 -0.097997 -0.428913 -0.288380
# Transmission           1.000000    0.001680  0.230786 -0.493003 -0.626902
# Owner_Type             0.001680    1.000000 -0.125967  0.048378  0.024743
# Mileage                0.230786   -0.125967  1.000000 -0.397745 -0.371827
# Engine                -0.493003    0.048378 -0.397745  1.000000  0.874967
# Power                 -0.626902    0.024743 -0.371827  0.874967  1.000000
# Seats                  0.084295    0.001168 -0.172380  0.362118  0.141659
# Price                 -0.632485   -0.171179 -0.176810  0.699523  0.778550
#
#                       Seats     Price
# Name               0.121723 -0.239868
# Location          -0.031139 -0.115545
# Year               0.016978  0.473132
# Kilometers_Driven  0.192039 -0.200195
# Fuel_Type         -0.285367 -0.396625
# Transmission       0.084295 -0.632485
# Owner_Type         0.001168 -0.171179
# Mileage           -0.172380 -0.176810
# Engine             0.362118  0.699523
# Power              0.141659  0.778550
# Seats              1.000000  0.131447
# Price              0.131447  1.000000

# %%
plt.figure(figsize=(20, 20))
cor = df_scaled.corr()
sns.heatmap(cor, cmap= "PiYG", annot=True)
plt.show()

# %%
def correlation(dataset, threshold):
  col_corr = set()
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if (corr_matrix.iloc[i, j]) > threshold:
          colname = corr_matrix.columns[i]
          col_corr.add(colname)
  return col_corr

# %%
var_to_remove = (correlation(df_scaled, 0.75))

# %%
var_to_remove.remove("Price")

# %%
var_to_remove
# Out:
# {'Power'}

# %%
# df_new = df_scaled.drop("Power", axis=1)

# %%
plt.scatter(df_rm["Owner_Type"], df_rm["Price"])
plt.xlabel("Owner_type")
plt.ylabel("Price")
plt.show()

# %%
for i in df.columns.drop("Name"):
  plt.scatter(df_rm[i], df_rm["Price"])
  plt.xlabel(f"{i}")
  plt.ylabel("Price")
  plt.xticks(rotation=45)
  plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df_rm, figsize=(20, 20), alpha = 0.8, diagonal="hist")  # diagonal -- kde for density distribution
plt.show()

# %%
import plotly.express as px

# %%
fig = px.pie(df_rm, names="Owner_Type", title="Pie Chart for Owner Type" )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5e446b5-56d1-4e42-808b-a73acce4f7ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5e446b5-56d1-4e42-808b-a73acce4f7ce")) {                    Plotly.newPlot(                        "e5e446b5-56d1-4e42-808b-a73acce4f7ce",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Owner_Type=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["First","First","First","First","Second","First","First","First","First","Second","First","First","First","First","Second","First","First","First","First","First","First","Second","First","First","First","First","First","Second","First","First","First","Second","First","Second","Second","First","First","First","First","Second","First","First","First","First","First","Second","First","First","Second","First","First","First","First","Third","First","First","First","First","First","First","First","First","Second","First","Second","First","First","First","First","First","First","First","Second","Second","First","First","First","First","First","First","First","First","First","Second","First","First","First","First","First","First","First","First","First","First","First","First","First","Second","First","First","First","Second","First","First","Second","Second","First","First","First","First","First","First","First","First","First","First","First","Second","Second","First","First","First","First","First","First","Second","First","First","First","First","First","First","First","Second","First","First","First","First","First","First","Third","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","Second","First","First","Second","First","First","First","Second","Second","Second","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","Second","First","First","First","First","First","First","First","First","First","First","Second","First","Second","First","First","First","Second","First","First","First","Second","Second","First","First","First","Second","First","First","First","Second","First","First","First","First","Second","First","First","First","First","First","First","First","First","Third","First","First","First","First","First","Second","First","First","First","First","Third","Second","First","First","First","First","First","Second","First","First","First","First","First","First","Second","First","Third","First","Second","First","First","First","First","First","First","Second","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","Second","First","First","First","First","First","First","Second","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","Third","First","First","Second","First","First","Second","Second","First","First","First","First","First","First","First","First","Second","First","First","First","First","First","Second","First","Third","First","First","First","First","First","First","First","First","First","First","Third","Second","Second","First","First","Third","First","Third","Second","First","First","Second","First","First","First","Second","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First","First
45,0.65,29.5,25.0,3.5,11.25,10.79,5.9,5.12,5.7,35.84,1.25,2.65,9.19,23.5,12.5,1.5,0.75,8.1,9.75,37.93,1.96,20.5,2.75,75.0,2.8,9.25,3.0,23.89,12.75,4.15,4.65,8.9,3.27,18.0,6.3,11.31,6.16,6.0,5.43,4.65,7.5,6.25,9.25,3.15,2.3,5.25,7.4,1.55,6.0,5.9,4.7,6.5,7.1,6.0,7.99,4.1,3.95,4.38,2.75,55.54,29.0,6.6,6.99,18.75,1.28,1.2,4.31,16.5,5.64,31.12,25.46,7.88,36.0,30.0,2.8 ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x="Fuel_Type", y="Price", data=df_rm)
plt.show()

# %%
cat_cols.remove("Name")

# %%
cat_cols
# Out:
# ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type']

# %%
for i in cat_cols:
  sns.boxplot(x=i, y="Price", data=df_rm)
  plt.xticks(rotation=45)
  plt.show()

# %%
cat_cols
# Out:
# ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type']

# %%
for i in cat_cols:
  plt.hist(df_rm[i], color="skyblue", edgecolor="Black")
  plt.title(f"Histogram of {i}")
  plt.xticks(rotation=45)
  plt.show()

# %%
num_cols = [x for x in df_rm if df_rm[x].dtype != "object"]

# %%
num_cols
# Out:
# ['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Price']

# %%
for i in num_cols:
  plt.figure(figsize=(10, 6))
  sns.kdeplot(data=df_rm[i])
  plt.title(f"KDE Plot of {i}")
  plt.xlabel(f"{i}")
  plt.show()

# %%
for i in df_rm.columns.drop('Name'):
  sns.lineplot(data=df_rm, x=i, y="Price")
  plt.title(f"{i} and Price Distribution")
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# # Excel Questions Solved

# %% [markdown]
# 1. What is the average selling price of used cars by brand?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_g = pd.read_csv("/content/used_cars.csv")

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
df_g.iloc[0,1].split()[0]
# Out:
# 'Maruti'

# %%
df_g["Name"]
# Out:
# 0                 Maruti Wagon R LXI CNG
# 1       Hyundai Creta 1.6 CRDi SX Option
# 2                           Honda Jazz V
# 3                      Maruti Ertiga VDI
# 4        Audi A4 New 2.0 TDI Multitronic
#                       ...
# 6014                    Maruti Swift VDI
# 6015            Hyundai Xcent 1.1 CRDi S
# 6016               Mahindra Xylo D4 BSIV
# 6017                  Maruti Wagon R VXI
# 6018               Chevrolet Beat Diesel
# Name: Name, Length: 6019, dtype: object

# %%
df_g["Brand"] = df_g["Name"].apply(lambda x: x.split()[0])

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price      Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75     Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50    Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00     Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       Audi
# ...       ...        ...    ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015  1120 CC     71 bhp    5.0        NaN   4.00    Hyundai
# 6016  2498 CC    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
# df_g.groupby("Brand").agg({"Price" : ["mean", "min", "max"]}).reset_index()

# %%
df_g.groupby("Brand").agg({"Price" : ["mean"]}).reset_index()
# Out:
#             Brand       Price
#                          mean
# 0      Ambassador    1.350000
# 1            Audi   25.537712
# 2             BMW   25.243146
# 3         Bentley   59.000000
# 4       Chevrolet    3.044463
# 5          Datsun    3.049231
# 6            Fiat    3.269286
# 7           Force    9.333333
# 8            Ford    6.889400
# 9           Honda    5.411743
# 10        Hyundai    5.343433
# 11          ISUZU   12.045000
# 12          Isuzu   20.000000
# 13         Jaguar   37.632250
# 14           Jeep   18.718667
# 15    Lamborghini  120.000000
# 16           Land   39.259500
# 17       Mahindra    8.045919
# 18         Maruti    4.517267
# 19  Mercedes-Benz   26.809874
# 20           Mini   26.896923
# 21     Mitsubishi   11.058889
# 22         Nissan    4.738352
# 23        Porsche   48.348333
# 24        Renault    5.799034
# 25          Skoda    7.559075
# 26          Smart    3.000000
# 27           Tata    3.562849
# 28         Toyota   11.580024
# 29     Volkswagen    5.307270
# 30          Volvo   18.802857

# %% [markdown]
# 2. How many cars are available per year?

# %%
q2 = df_g["Year"].value_counts().reset_index()

# %%
q2
# Out:
#     Year  count
# 0   2014    797
# 1   2015    744
# 2   2016    741
# 3   2013    649
# 4   2017    587
# 5   2012    580
# 6   2011    466
# 7   2010    342
# 8   2018    298
# 9   2009    198
# 10  2008    174
# 11  2007    125
# 12  2019    102
# 13  2006     78
# 14  2005     57
# 15  2004     31
# 16  2003     17
# 17  2002     15
# 18  2001      8
# 19  2000      4
# 20  1998      4
# 21  1999      2

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=q2, x="Year", y="count")
plt.title("Cars Available Per Year")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 3. What is the average mileage (kmpl/km/kg) by fuel type?

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price      Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75     Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50    Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00     Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       Audi
# ...       ...        ...    ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015  1120 CC     71 bhp    5.0        NaN   4.00    Hyundai
# 6016  2498 CC    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
def clean_mileage(mileage):
  return float(str(mileage).split()[0]) if pd.notna(mileage) else None

def clean_engine(engine):
  return float(str(engine).split()[0]) if pd.notna(engine) else None

def clean_power(power):
  return float(str(power).split()[0]) if pd.notna(power) and power!= "null bhp" else None

# %%
df_g["Mileage"] = df_g["Mileage"].apply(clean_mileage)

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage   Engine  \
# 0                 72000       CNG       Manual      First    26.60   998 CC
# 1                 41000    Diesel       Manual      First    19.67  1582 CC
# 2                 46000    Petrol       Manual      First    18.20  1199 CC
# 3                 87000    Diesel       Manual      First    20.77  1248 CC
# 4                 40670    Diesel    Automatic     Second    15.20  1968 CC
# ...                 ...       ...          ...        ...      ...      ...
# 6014              27365    Diesel       Manual      First    28.40  1248 CC
# 6015             100000    Diesel       Manual      First    24.40  1120 CC
# 6016              55000    Diesel       Manual     Second    14.00  2498 CC
# 6017              46000    Petrol       Manual      First    18.90   998 CC
# 6018              47000    Diesel       Manual      First    25.44   936 CC
#
#           Power  Seats  New_Price  Price      Brand
# 0     58.16 bhp    5.0        NaN   1.75     Maruti
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     88.76 bhp    7.0        NaN   6.00     Maruti
# 4     140.8 bhp    5.0        NaN  17.74       Audi
# ...         ...    ...        ...    ...        ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015     71 bhp    5.0        NaN   4.00    Hyundai
# 6016    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
q3 = df_g.groupby("Fuel_Type").agg({"Mileage" : "mean"}).reset_index()

# %%
import plotly.express as px

# %%
q3
# Out:
#   Fuel_Type    Mileage
# 0       CNG  25.418036
# 1    Diesel  18.620484
# 2  Electric        NaN
# 3       LPG  19.385000
# 4    Petrol  17.415204

# %%
fig = px.pie(q3, names="Fuel_Type", values="Mileage")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28a84bce-5d09-463f-a36d-9db87d9658b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28a84bce-5d09-463f-a36d-9db87d9658b4")) {                    Plotly.newPlot(                        "28a84bce-5d09-463f-a36d-9db87d9658b4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Fuel_Type=%{label}\u003cbr\u003eMileage=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["CNG","Diesel","Electric","LPG","Petrol"],"legendgroup":"","name":"","showlegend":true,"values":[25.418035714285715,18.620483619344775,null,19.384999999999998,17.415203932993446],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{ ...

# %% [markdown]
# 4. What is the distribution of cars by transmission type?

# %%
# df_g.groupby("Transmission").agg({"Location" : "count"})
# Out:
#               Location
# Transmission
# Automatic         1720
# Manual            4299

# %%
q4 = df_g["Transmission"].value_counts().reset_index()

# %%
fig = px.pie(q4, names = 'Transmission',values="count", title = 'Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c8ccdca5-9f01-4ef8-a864-7c70fbb5a396" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8ccdca5-9f01-4ef8-a864-7c70fbb5a396")) {                    Plotly.newPlot(                        "c8ccdca5-9f01-4ef8-a864-7c70fbb5a396",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Transmission=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Manual","Automatic"],"legendgroup":"","name":"","showlegend":true,"values":[4299,1720],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{ ...

# %% [markdown]
# 5. Which Owner type offers the most cars, and what's the average selling price?

# %%
q5 = df_g.groupby("Owner_Type").agg({"Name":"count", "Price":"mean"}).reset_index()

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.bar(q5["Owner_Type"], q5["Name"], color='skyblue', label="Car Count")
ax1.set_ylabel("Car Count", color='black')
ax1.tick_params(axis='y', labelcolor='black')

ax2 = ax1.twinx()
ax2.plot(q5["Owner_Type"], q5["Price"], color='red', marker='o', label="Avg Price")
ax2.set_ylabel("Average Price", color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title("Car Count and Average Price by Owner Type")
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Which year has the highest average selling price?

# %%
year_price = df_g.groupby("Year").agg({"Price" : "mean"}).reset_index()

# %%
(year_price.sort_values(by="Price", ascending=False)).iloc[0, ]
# Out:
# Year     2019.000000
# Price      19.464118
# Name: 21, dtype: float64

# %% [markdown]
# 7. What is the relationship between engine size (binned) and price?

# %%
df_g["Engine"] = df_g["Engine"].apply(clean_engine)

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 72000       CNG       Manual      First    26.60   998.0
# 1                 41000    Diesel       Manual      First    19.67  1582.0
# 2                 46000    Petrol       Manual      First    18.20  1199.0
# 3                 87000    Diesel       Manual      First    20.77  1248.0
# 4                 40670    Diesel    Automatic     Second    15.20  1968.0
# ...                 ...       ...          ...        ...      ...     ...
# 6014              27365    Diesel       Manual      First    28.40  1248.0
# 6015             100000    Diesel       Manual      First    24.40  1120.0
# 6016              55000    Diesel       Manual     Second    14.00  2498.0
# 6017              46000    Petrol       Manual      First    18.90   998.0
# 6018              47000    Diesel       Manual      First    25.44   936.0
#
#           Power  Seats  New_Price  Price      Brand
# 0     58.16 bhp    5.0        NaN   1.75     Maruti
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     88.76 bhp    7.0        NaN   6.00     Maruti
# 4     140.8 bhp    5.0        NaN  17.74       Audi
# ...         ...    ...        ...    ...        ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015     71 bhp    5.0        NaN   4.00    Hyundai
# 6016    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
df_g["engine_size_bin"] = pd.cut(df_g["Engine"], bins=[0, 1000, 2000, 3000, 4000, 5000, 6000])

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 72000       CNG       Manual      First    26.60   998.0
# 1                 41000    Diesel       Manual      First    19.67  1582.0
# 2                 46000    Petrol       Manual      First    18.20  1199.0
# 3                 87000    Diesel       Manual      First    20.77  1248.0
# 4                 40670    Diesel    Automatic     Second    15.20  1968.0
# ...                 ...       ...          ...        ...      ...     ...
# 6014              27365    Diesel       Manual      First    28.40  1248.0
# 6015             100000    Diesel       Manual      First    24.40  1120.0
# 6016              55000    Diesel       Manual     Second    14.00  2498.0
# 6017              46000    Petrol       Manual      First    18.90   998.0
# 6018              47000    Diesel       Manual      First    25.44   936.0
#
#           Power  Seats  New_Price  Price      Brand engine_size_bin
# 0     58.16 bhp    5.0        NaN   1.75     Maruti       (0, 1000]
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai    (1000, 2000]
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda    (1000, 2000]
# 3     88.76 bhp    7.0        NaN   6.00     Maruti    (1000, 2000]
# 4     140.8 bhp    5.0        NaN  17.74       Audi    (1000, 2000]
# ...         ...    ...        ...    ...        ...             ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti    (1000, 2000]
# 6015     71 bhp    5.0        NaN   4.00    Hyundai    (1000, 2000]
# 6016    112 bhp    8.0        NaN   2.90   Mahindra    (2000, 3000]
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti       (0, 1000]
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet       (0, 1000]
#
# [6019 rows x 16 columns]

# %%
q7 = df_g.groupby("engine_size_bin").agg({"Price" : "mean"}).reset_index()
# Out:
# <ipython-input-54-909db014aea4>:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
q7["engine_size_bin"] = q7["engine_size_bin"].astype(str)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=q7, x="engine_size_bin", y="Price")
plt.title("relationship between engine size and price")
plt.xticks(rotation=45)
plt.show()
